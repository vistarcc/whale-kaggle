# %% [markdown]
# # Key notes
#
#
# 运行前请修改一下路径名或参数值：
#
# [1]base_path = "./data/whale/train_full/" ，原始train image的存放路径
#
# [2]data = pd.read_csv('./data/whale/train.csv')，train.csv的存放路径
#
# [3]train_files = glob.glob("./data/whale/train_full/*.jpg")，原始train image的存放路径
#
# [4]test_files = glob.glob("./data/whale/test/*.jpg")，原始test image的存放路径
#
# [5]最后会在当前目录下生成一个sub_triplet_loss.csv预测文件，即kaggle规定的submission文件
#
# [6]如果laptop运行，GPU内存不到8G，有可能会发生OOM溢出，可以适当减少batch_size
#
#
#
# 模型要点：
#
# 1.主框架模型时siamese + triplet loss, 求每个image的embedding（长度为50的vector）时用了resNet50模型
#
# 2.triplet loss使用了Bayesian Personalized Ranking loss
#
# 3.预处理只做了resize to (256, 256)和convert to RGB, 以及小概率(10%)的fliplr，没有做augment
#
# 4.挑选triplet的时候没有刻意去挑选（像andrew ng的video和那篇paper里面说的那样，需要刻意去挑选，以提升性能。
#
# 5.在生产训练batch的时候，用了generator + yield，所有batch的生成都是on the fly，大大减少了memory的消耗
#
# 6.模型训练完之后，将所有的train images和test images的embedding都计算出来，在embedding（长度只有50）的基础上再做test images的预测，这样大大提升了预测速度
#
# 7.预测用了knn算法，最后选取最近的5个class id
#
# 8.因为new whale有大概率出现（9850个train images出现了810次），这里强制把new whale在knn的distance设置为0.1（有待商榷）
#
# 9.注意建模训练的时候，new_whale的样本是没有参与train的
#
# 总结：最粗糙暴力的方法，最后的MAP有0.42左右，排名还挺高，可以考虑在这个基础上优化。
#
# 优化方向：
#
# 1.preprocessing
#
# 2.augmentation
#
# 3.the way to choose triplet
#
# 4.the knn default distance for new_whale 0.1 ??
#
# 5.make use of the test images, for example autoencoder

# %%
#part of the code is from https://github.com/maciejkula/triplet_recommendations_keras

from collections import defaultdict
import numpy as np
from sklearn.model_selection import train_test_split
import pandas as pd
from keras import backend as K
from keras.models import Model
from keras.layers import Embedding, Flatten, Input, merge
from keras.optimizers import Adam
from keras.layers import Conv2D, MaxPooling2D, Input, Dense, Flatten, GlobalMaxPooling2D
import glob
import os
from PIL import Image
from keras.callbacks import ModelCheckpoint, LearningRateScheduler, EarlyStopping, ReduceLROnPlateau, TensorBoard
from keras import optimizers, losses, activations, models
from keras.layers import Convolution2D, Dense, Input, Flatten, Dropout, MaxPooling2D, BatchNormalization, \
    GlobalMaxPool2D, Concatenate, GlobalMaxPooling2D, GlobalAveragePooling2D, Lambda
from keras.applications.resnet50 import ResNet50
from sklearn.neighbors import NearestNeighbors  
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
from keras.utils.training_utils import multi_gpu_model

# %%
class sample_gen(object):
    def __init__(self, file_class_mapping, other_class = "new_whale"):
        self.file_class_mapping= file_class_mapping
        self.class_to_list_files = defaultdict(list)
        self.list_other_class = []
        self.list_all_files = list(file_class_mapping.keys())
        self.range_all_files = list(range(len(self.list_all_files)))

        for file, class_ in file_class_mapping.items():
            if class_ == other_class:
                self.list_other_class.append(file)
            else:
                self.class_to_list_files[class_].append(file)

#       注意这里的去除了重复class id
        self.list_classes = list(set(self.file_class_mapping.values()))
        self.range_list_classes= range(len(self.list_classes))#包含了new_whale
#       每个class（Id）的比重，相当于直方图  
        self.class_weight = np.array([len(self.class_to_list_files[class_]) for class_ in self.list_classes]) * 1.0
#         self.class_weight = self.class_weight/np.sum(self.class_weight)
        
#       new_whale的class_weight是0
        self.class_weight /= self.class_weight.sum()
        print "sum=", self.class_weight.sum()

#   这个函数只是返回一个triplet样例
    def get_sample(self):
#       按class id比重抽取一个样本，因为new_whale的weight是0，所以不会被抽取到
        class_idx = np.random.choice(self.range_list_classes, 1, p=self.class_weight)[0]
#       对这种class id的，抽取两个样本images (如果某个class只有一个样本，那么返回的是两个一样的image)
        examples_class_idx = np.random.choice(range(len(self.class_to_list_files[self.list_classes[class_idx]])), 2)
#       注意这两个样本属于同一个class
        positive_example_1, positive_example_2 = \
            self.class_to_list_files[self.list_classes[class_idx]][examples_class_idx[0]],\
            self.class_to_list_files[self.list_classes[class_idx]][examples_class_idx[1]]

#       提取一个跟positive_example_1不同class的样本
        negative_example = None
        while negative_example is None or self.file_class_mapping[negative_example] == \
                self.file_class_mapping[positive_example_1]:
            negative_example_idx = np.random.choice(self.range_all_files, 1)[0]
            negative_example = self.list_all_files[negative_example_idx]
        return positive_example_1, negative_example, positive_example_2



GPU_num = 2
batch_size = 8
input_shape = (256, 256)
base_path = "./data/whale/train_full/"

# 就是返回了y_pred的平均值
def identity_loss(y_true, y_pred):

    return K.mean(y_pred - 0 * y_true)

# Bayesian Personalized Ranking loss
def bpr_triplet_loss(X):

    positive_item_latent, negative_item_latent, user_latent = X

    # BPR loss
    loss = 1.0 - K.sigmoid(
        K.sum(user_latent * positive_item_latent, axis=-1, keepdims=True) -
        K.sum(user_latent * negative_item_latent, axis=-1, keepdims=True))

    return loss

def euclid_triplet_loss(X, margin=0.2):
    
    positive_item_latent, negative_item_latent, user_latent = X
    
    #Euclid distance triplet loss
    loss = K.maximum(K.sum(K.square(user_latent - positive_item_latent), axis=-1, keepdims=True) 
                     - K.sum(K.square(user_latent - negative_item_latent), axis=-1, keepdims=True) + margin, 0)
    
    return loss

def get_base_model():
    latent_dim = 256
#   include_top：whether to include the fully-connected layer at the top of the network.
    base_model = ResNet50(weights='imagenet',include_top=False) # use weights='imagenet' locally

    # for layer in base_model.layers:
    #     layer.trainable = False

    x = base_model.output
    x = GlobalMaxPooling2D()(x)
    x = Dropout(0.5)(x)
    dense_1 = Dense(latent_dim)(x)
    normalized = Lambda(lambda  x: K.l2_normalize(x,axis=1))(dense_1)
#   相当于对这50长度的vector，每个元素取平方，方便后面的距离计算
    base_model = Model(base_model.input, normalized, name="base_model")
    return base_model

def build_model():
    base_model = get_base_model()
#   input结构变成(256, 256, 3)
    positive_example_1 = Input(input_shape+(3,) , name='positive_example_1')
    negative_example = Input(input_shape+(3,), name='negative_example')
    positive_example_2 = Input(input_shape+(3,), name='positive_example_2')

    positive_example_1_out = base_model(positive_example_1)
    negative_example_out = base_model(negative_example)
    positive_example_2_out = base_model(positive_example_2)

#   用triplet loss的方式对三个embedding进行merge,输出是一个sigmoid
    loss = merge(
        [positive_example_1_out, negative_example_out, positive_example_2_out],
        mode=euclid_triplet_loss,
        name='loss',
        output_shape=(1, ))

#     model = Model(
#         input=[positive_example_1, negative_example, positive_example_2],
#         output=loss)
    
    # check to see if we are compiling using just a single GPU
    if GPU_num <= 1:
        print("[INFO] training with 1 GPU...")
        model = Model(input=[positive_example_1, negative_example, positive_example_2],output=loss)
    # otherwise, we are compiling using multiple GPUs
    else:
        print("[INFO] training with {} GPUs...".format(GPU_num))

        # we'll store a copy of the model on *every* GPU and then combine
        # the results from the gradient updates on the CPU
        with tf.device("/cpu:0"):
            # initialize the model
            model = Model(input=[positive_example_1, negative_example, positive_example_2],output=loss)

        # make the model parallel
        model = multi_gpu_model(model, gpus=GPU_num)    
        
    model.compile(loss=identity_loss, optimizer=Adam(0.000001))

    print(model.summary())

    return model


model_name = "triplet_model"

file_path = model_name + "weights.best.hdf5"



def build_inference_model(weight_path=file_path):
    base_model = get_base_model()

    positive_example_1 = Input(input_shape+(3,) , name='positive_example_1')
    negative_example = Input(input_shape+(3,), name='negative_example')
    positive_example_2 = Input(input_shape+(3,), name='positive_example_2')

    positive_example_1_out = base_model(positive_example_1)
    negative_example_out = base_model(negative_example)
    positive_example_2_out = base_model(positive_example_2)

    loss = merge(
        [positive_example_1_out, negative_example_out, positive_example_2_out],
        mode=bpr_triplet_loss,
        name='loss',
        output_shape=(1, ))

    model = Model(
        input=[positive_example_1, negative_example, positive_example_2],
        output=loss)
    model.compile(loss=identity_loss, optimizer=Adam(0.000001))

#   导入前面训练出来的权重
    model.load_weights(weight_path)

#   base model只包含了把input转为embedding的过程，没有包含后面的triplet loss部分
    inference_model = Model(base_model.get_input_at(0), output=base_model.get_output_at(0))
    inference_model.compile(loss="mse", optimizer=Adam(0.000001))
    print(inference_model.summary())

    return inference_model

def read_and_resize(filepath):
#   这里不是用的grayscale，而是转成RGB了
    im = Image.open((filepath)).convert('RGB')
    im = im.resize(input_shape)
#   im的shape变成（256， 256， 3）
    im_array = np.array(im, dtype="uint8")[..., ::-1] #这个是对RGB进行逆序？？
#   转换成float类型
    return np.array(im_array / (np.max(im_array)+ 0.001), dtype="float32")

# 进行小概率的augment
def augment(im_array):
    if np.random.uniform(0, 1) > 0.9:
#       fliplr只对第1维度column进行flip
        im_array = np.fliplr(im_array)
    return im_array


datagen_args = dict(rotation_range=10,
                    width_shift_range=0.2,
                    height_shift_range=0.2,
                    shear_range=0.2,
                    zoom_range=0.2,
                    horizontal_flip=True)

datagen = ImageDataGenerator(**datagen_args)

# 进行大概率的augment，更复杂
def augment_v2(im_array):
    if np.random.uniform(0, 1) > 0.25:
        im_array = datagen.random_transform(im_array)
    return im_array

# 这个函数返回一个generator
def gen(triplet_gen):
    while True:
        list_positive_examples_1 = []
        list_negative_examples = []
        list_positive_examples_2 = []

#       会有重复抽样 bootstrap
        for i in range(batch_size):
            positive_example_1, negative_example, positive_example_2 = triplet_gen.get_sample()
            positive_example_1_img, negative_example_img, positive_example_2_img = read_and_resize(base_path+positive_example_1), \
                                                                       read_and_resize(base_path+negative_example), \
                                                                       read_and_resize(base_path+positive_example_2)
#           这个增强并没有增加训练样本数，而是替换了原样本
            positive_example_1_img, negative_example_img, positive_example_2_img = augment_v2(positive_example_1_img), \
                                                                                   augment_v2(negative_example_img), \
                                                                                   augment_v2(positive_example_2_img)

            list_positive_examples_1.append(positive_example_1_img)
            list_negative_examples.append(negative_example_img)
            list_positive_examples_2.append(positive_example_2_img)

        list_positive_examples_1 = np.array(list_positive_examples_1)
        list_negative_examples = np.array(list_negative_examples)
        list_positive_examples_2 = np.array(list_positive_examples_2)
        
#       利用yield，返回一个generator, 并且call on the fly (通过yield + while True)，节省内存
#       注意配合model.fit_generator使用的generator返回值必须是（input, target），所以后面的np.ones(batch_size)相当于target (即label)
#       只不过在这个模型里面这个target没有被用上而已
#       最后注意每次yield返回一个batch的samples
        yield [list_positive_examples_1, list_negative_examples, list_positive_examples_2], np.ones(batch_size)

    
def sort_by_anchor_negative_distance(anchor_examples, negative_examples, positive_examples, latest_model):
    lastest_saved_path = 'triplet_modelweights.best.hdf5'
    if os.path.isfile(lastest_saved_path):
#         latest_model = build_inference_model()
        
        distances = []
        anchor_embeddings = latest_model.predict(np.array(anchor_examples), batch_size=2)
        negative_embeddings = latest_model.predict(np.array(negative_examples), batch_size=2)
        for i in range(anchor_embeddings.shape[0]):
#             anchor_embedding = anchor_embeddings[i]
#             negative_embedding = negative_embeddings[i]
            distances.append(np.sum(np.square(anchor_embeddings[i] - negative_embeddings[i])))
            
        values = []
        for anchor, negative, positive, distance in zip(anchor_examples, negative_examples, positive_examples, distances):
            values.append((anchor, negative, positive, distance))
        
        dtype = [('anchor', np.float32), ('negative', np.float32), ('positive', np.float32), ('distance', np.float32)]
        values_array = np.array(values, dtype=dtype)
        array_sorted = np.sort(values_array, order='distance')
        
        anchor_examples_sort = []
        negative_examples_sort = []
        positive_examples_sort = []
        
        for i in range(array_sorted.shape[0]):
            anchor_examples_sort.append(array_sorted[i][0])
            negative_examples_sort.append(array_sorted[i][1])
            positive_examples_sort.append(array_sorted[i][2])
        return np.array(anchor_examples_sort), np.array(negative_examples_sort), np.array(positive_examples_sort)
    else:
        return np.array(anchor_examples), np.array(negative_examples), np.array(positive_examples)
    
# 这个函数返回一个generator
# 使用了“FaceNet: A Unified Embedding for Face Recognition and Clustering” 推荐的online hard triplets selection方法
# 用一个latest best model来做筛选，但只对hard negative进行筛选 (semi-hard)
def gen_with_online_selection(triplet_gen, latest_model, batch_candidates=30, cutoff=0.5):
    while True:
        list_positive_examples_1 = []
        list_negative_examples = []
        list_positive_examples_2 = []
        
        
#       会有重复抽样
#       随机筛选30个triplets作为candidates，然后从中选取
        for i in range(batch_candidates):
            positive_example_1, negative_example, positive_example_2 = triplet_gen.get_sample()
            positive_example_1_img, negative_example_img, positive_example_2_img = read_and_resize(base_path+positive_example_1), \
                                                                       read_and_resize(base_path+negative_example), \
                                                                       read_and_resize(base_path+positive_example_2)
#           这个增强并没有增加训练样本数，而是替换了原样本
            positive_example_1_img, negative_example_img, positive_example_2_img = augment_v2(positive_example_1_img), \
                                                                                   augment_v2(negative_example_img), \
                                                                                   augment_v2(positive_example_2_img)

            list_positive_examples_1.append(positive_example_1_img)
            list_negative_examples.append(negative_example_img)
            list_positive_examples_2.append(positive_example_2_img)

#         list_positive_examples_1 = np.array(list_positive_examples_1)
#         list_negative_examples = np.array(list_negative_examples)
#         list_positive_examples_2 = np.array(list_positive_examples_2)
        
        list_positive_examples_1, list_negative_examples, list_positive_examples_2 = \
        sort_by_anchor_negative_distance(list_positive_examples_1, list_negative_examples, list_positive_examples_2, latest_model)
        
#       从最小的(cutoff=50%)anchor-negative distance examples中，随机选取batch_size个examples用来训练模型
        idx = np.random.permutation(int(batch_candidates * cutoff))[:batch_size]
        
#       利用yield，返回一个generator, 并且call on the fly (通过yield + while True)，节省内存
#       注意配合model.fit_generator使用的generator返回值必须是（input, target），所以后面的np.ones(batch_size)相当于target (即label)
#       只不过在这个模型里面这个target没有被用上而已
#       最后注意每次yield返回一个batch的samples
        yield [list_positive_examples_1[idx], list_negative_examples[idx], list_positive_examples_2[idx]], np.ones(batch_size)

# %%
num_epochs = 300

# Read data
data = pd.read_csv('./data/whale/train.csv')
train, test = train_test_split(data, test_size=0.3, shuffle=True, random_state=1337)
#把image作为key，id作为value
file_id_mapping_train = {k: v for k, v in zip(train.Image.values, train.Id.values)}
file_id_mapping_test = {k: v for k, v in zip(test.Image.values, test.Id.values)}
train_gen = sample_gen(file_id_mapping_train)
test_gen = sample_gen(file_id_mapping_test)
# Out:
# sum= 1.0
# sum= 0.9999999999999999

# %%
# Prepare the test triplets

model = build_model()



#model.load_weights(file_path)

# 根据monitor的值即loss，保存loss最小(min)时的model (best model)
checkpoint = ModelCheckpoint(file_path, monitor='val_loss', verbose=1, save_best_only=True, mode='min')

early = EarlyStopping(monitor="val_loss", mode="min", patience=15)

callbacks_list = [checkpoint, early]  # early

# Trains the model on data generated batch-by-batch by a Python generator
# 这种模式，generate bath on the fly，可以节省很多memory，因而可以使用更大的batch size
history = model.fit_generator(gen(train_gen), validation_data=gen(test_gen), epochs=num_epochs, verbose=2, workers=1, use_multiprocessing=False,
                              callbacks=callbacks_list, steps_per_epoch=20000, validation_steps=3600)
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:109: UserWarning: The `merge` function is deprecated and will be removed after 08/2017. Use instead layers from `keras.layers.merge`, e.g. `add`, `concatenate`, etc.
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:113: UserWarning: Update your `Model` call to the Keras 2 API: `Model(outputs=Tensor("lo..., inputs=[<tf.Tenso...)`
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# positive_example_1 (InputLayer) (None, 256, 256, 3)  0
# __________________________________________________________________________________________________
# negative_example (InputLayer)   (None, 256, 256, 3)  0
# __________________________________________________________________________________________________
# positive_example_2 (InputLayer) (None, 256, 256, 3)  0
# __________________________________________________________________________________________________
# base_model (Model)              (None, 256)          24112256    positive_example_1[0][0]
#                                                                  negative_example[0][0]
#                                                                  positive_example_2[0][0]
# __________________________________________________________________________________________________
# loss (Merge)                    (None, 1)            0           base_model[1][0]
#                                                                  base_model[2][0]
#                                                                  base_model[3][0]
# ==================================================================================================
# Total params: 24,112,256
# Trainable params: 24,059,136
# Non-trainable params: 53,120
# __________________________________________________________________________________________________
# None
# Epoch 1/300
#  - 5446s - loss: 0.0513 - val_loss: 0.0154
#
# Epoch 00001: val_loss improved from inf to 0.01544, saving model to triplet_modelweights.best.hdf5
# Epoch 2/300
#  - 5376s - loss: 0.0303 - val_loss: 0.0114
#
# Epoch 00002: val_loss improved from 0.01544 to 0.01141, saving model to triplet_modelweights.best.hdf5
# Epoch 3/300
#  - 5374s - loss: 0.0237 - val_loss: 0.0109
#
# Epoch 00003: val_loss improved from 0.01141 to 0.01092, saving model to triplet_modelweights.best.hdf5
# Epoch 4/300
#  - 5370s - loss: 0.0186 - val_loss: 0.0110
#
# Epoch 00004: val_loss did not improve from 0.01092
# Epoch 5/300
#  - 5370s - loss: 0.0161 - val_loss: 0.0080
#
# Epoch 00005: val_loss improved from 0.01092 to 0.00802, saving model to triplet_modelweights.best.hdf5
# Epoch 6/300
#  - 5368s - loss: 0.0139 - val_loss: 0.0093
#
# Epoch 00006: val_loss did not improve from 0.00802
# Epoch 7/300
#  - 5368s - loss: 0.0119 - val_loss: 0.0077
#
# Epoch 00007: val_loss improved from 0.00802 to 0.00771, saving model to triplet_modelweights.best.hdf5
# Epoch 8/300
#  - 5366s - loss: 0.0105 - val_loss: 0.0080
#
# Epoch 00008: val_loss did not improve from 0.00771
# Epoch 9/300
#  - 5366s - loss: 0.0095 - val_loss: 0.0067
#
# Epoch 00009: val_loss improved from 0.00771 to 0.00672, saving model to triplet_modelweights.best.hdf5
# Epoch 10/300
#  - 5365s - loss: 0.0087 - val_loss: 0.0072
#
# Epoch 00010: val_loss did not improve from 0.00672
# Epoch 11/300
#  - 5365s - loss: 0.0078 - val_loss: 0.0069
#
# Epoch 00011: val_loss did not improve from 0.00672
# Epoch 12/300
#  - 5365s - loss: 0.0069 - val_loss: 0.0061
#
# Epoch 00012: val_loss improved from 0.00672 to 0.00612, saving model to triplet_modelweights.best.hdf5
# Epoch 13/300
#  - 5366s - loss: 0.0064 - val_loss: 0.0064
#
# Epoch 00013: val_loss did not improve from 0.00612
# Epoch 14/300
#  - 5363s - loss: 0.0060 - val_loss: 0.0059
#
# Epoch 00014: val_loss improved from 0.00612 to 0.00587, saving model to triplet_modelweights.best.hdf5
# Epoch 15/300
#  - 5364s - loss: 0.0055 - val_loss: 0.0054
#
# Epoch 00015: val_loss improved from 0.00587 to 0.00540, saving model to triplet_modelweights.best.hdf5
# Epoch 16/300
#  - 5362s - loss: 0.0050 - val_loss: 0.0057
#
# Epoch 00016: val_loss did not improve from 0.00540
# Epoch 17/300
#  - 5361s - loss: 0.0049 - val_loss: 0.0057
#
# Epoch 00017: val_loss did not improve from 0.00540
# Epoch 18/300
#  - 5360s - loss: 0.0043 - val_loss: 0.0054
#
# Epoch 00018: val_loss improved from 0.00540 to 0.00535, saving model to triplet_modelweights.best.hdf5
# Epoch 19/300
#  - 5362s - loss: 0.0043 - val_loss: 0.0053
#
# Epoch 00019: val_loss improved from 0.00535 to 0.00530, saving model to triplet_modelweights.best.hdf5
# Epoch 20/300
#  - 5361s - loss: 0.0040 - val_loss: 0.0049
#
# Epoch 00020: val_loss improved from 0.00530 to 0.00491, saving model to triplet_modelweights.best.hdf5
# Epoch 21/300
#  - 5362s - loss: 0.0040 - val_loss: 0.0053
#
# Epoch 00021: val_loss did not improve from 0.00491
# Epoch 22/300
#  - 5362s - loss: 0.0035 - val_loss: 0.0054
#
# Epoch 00022: val_loss did not improve from 0.00491
# Epoch 23/300
#  - 5361s - loss: 0.0033 - val_loss: 0.0058
#
# Epoch 00023: val_loss did not improve from 0.00491
# Epoch 24/300
#  - 5362s - loss: 0.0031 - val_loss: 0.0055
#
# Epoch 00024: val_loss did not improve from 0.00491
# Epoch 25/300
#  - 5359s - loss: 0.0030 - val_loss: 0.0047
#
# Epoch 00025: val_loss improved from 0.00491 to 0.00470, saving model to triplet_modelweights.best.hdf5
# Epoch 26/300
#  - 5362s - loss: 0.0030 - val_loss: 0.0062
#
# Epoch 00026: val_loss did not improve from 0.00470
# Epoch 27/300
#  - 5360s - loss: 0.0029 - val_loss: 0.0049
#
# Epoch 00027: val_loss did not improve from 0.00470
# Epoch 28/300
#  - 5359s - loss: 0.0027 - val_loss: 0.0050
#
# Epoch 00028: val_loss did not improve from 0.00470
# Epoch 29/300
#  - 5361s - loss: 0.0025 - val_loss: 0.0049
#
# Epoch 00029: val_loss did not improve from 0.00470
# Epoch 30/300
#  - 5358s - loss: 0.0024 - val_loss: 0.0049
#
# Epoch 00030: val_loss did not improve from 0.00470
# Epoch 31/300
#  - 5361s - loss: 0.0024 - val_loss: 0.0054
#
# Epoch 00031: val_loss did not improve from 0.00470
# Epoch 32/300
#  - 5359s - loss: 0.0023 - val_loss: 0.0052
#
# Epoch 00032: val_loss did not improve from 0.00470
# Epoch 33/300
#  - 5358s - loss: 0.0022 - val_loss: 0.0051
#
# Epoch 00033: val_loss did not improve from 0.00470
# Epoch 34/300
#  - 5359s - loss: 0.0022 - val_loss: 0.0054
#
# Epoch 00034: val_loss did not improve from 0.00470
# Epoch 35/300
#  - 5361s - loss: 0.0021 - val_loss: 0.0051
#
# Epoch 00035: val_loss did not improve from 0.00470
# Epoch 36/300
#  - 5361s - loss: 0.0020 - val_loss: 0.0052
#
# Epoch 00036: val_loss did not improve from 0.00470
# Epoch 37/300
#  - 5362s - loss: 0.0020 - val_loss: 0.0048
#
# Epoch 00037: val_loss did not improve from 0.00470
# Epoch 38/300
#  - 5361s - loss: 0.0019 - val_loss: 0.0049
#
# Epoch 00038: val_loss did not improve from 0.00470
# Epoch 39/300
#  - 5358s - loss: 0.0018 - val_loss: 0.0056
#
# Epoch 00039: val_loss did not improve from 0.00470
# Epoch 40/300
#  - 5357s - loss: 0.0016 - val_loss: 0.0057
#
# Epoch 00040: val_loss did not improve from 0.00470

# %%
model_name = "triplet_loss"
def data_generator(fpaths, batch=16):
    i = 0
    for path in fpaths:
        if i == 0:
            imgs = []
            fnames = []
        i += 1
        img = read_and_resize(path)
        imgs.append(img)
#       获取image的名字
        fnames.append(os.path.basename(path))
        if i == batch:
            i = 0
            imgs = np.array(imgs)
#           每次yield返回一个batch的samples
            yield fnames, imgs
    if i < batch:
        imgs = np.array(imgs)
        yield fnames, imgs
    raise StopIteration()

data = pd.read_csv('./data/whale/train.csv')

file_id_mapping = {k: v for k, v in zip(data.Image.values, data.Id.values)}

inference_model = build_inference_model()

# 文件名匹配，返回一个list包含所有这个后缀的文件path
train_files = glob.glob("./data/whale/train_full/*.jpg")
test_files = glob.glob("./data/whale/test/*.jpg")

train_preds = []
train_file_names = []
i = 1
# 每个imgs里面包含的是一个batch的samples
for fnames, imgs in data_generator(train_files, batch=32):
#     print(i*32/len(train_files)*100)
    i += 1
    predicts = inference_model.predict(imgs)
#   将一个batch的images转换成embeddings，然后转成list
    predicts = predicts.tolist()
    train_preds += predicts
    train_file_names += fnames

#  得到了所有train images的embeddings
train_preds = np.array(train_preds)

test_preds = []
test_file_names = []
i = 1
for fnames, imgs in data_generator(test_files, batch=32):
#     print(i * 32 / len(test_files) * 100)
    i += 1
    predicts = inference_model.predict(imgs)
    predicts = predicts.tolist()
    test_preds += predicts
    test_file_names += fnames

#  得到了所有test images的embeddings
test_preds = np.array(test_preds)
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:142: UserWarning: The `merge` function is deprecated and will be removed after 08/2017. Use instead layers from `keras.layers.merge`, e.g. `add`, `concatenate`, etc.
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:146: UserWarning: Update your `Model` call to the Keras 2 API: `Model(outputs=Tensor("lo..., inputs=[<tf.Tenso...)`
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:153: UserWarning: Update your `Model` call to the Keras 2 API: `Model(Tensor("in..., outputs=Tensor("la...)`
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_12 (InputLayer)           (None, None, None, 3 0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, None, None, 3 0           input_12[0][0]
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, None, None, 6 9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# bn_conv1 (BatchNormalization)   (None, None, None, 6 256         conv1[0][0]
# __________________________________________________________________________________________________
# activation_540 (Activation)     (None, None, None, 6 0           bn_conv1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_12 (MaxPooling2D) (None, None, None, 6 0           activation_540[0][0]
# __________________________________________________________________________________________________
# res2a_branch2a (Conv2D)         (None, None, None, 6 4160        max_pooling2d_12[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2a (BatchNormalizati (None, None, None, 6 256         res2a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_541 (Activation)     (None, None, None, 6 0           bn2a_branch2a[0][0]
# __________________________________________________________________________________________________
# res2a_branch2b (Conv2D)         (None, None, None, 6 36928       activation_541[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2b (BatchNormalizati (None, None, None, 6 256         res2a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_542 (Activation)     (None, None, None, 6 0           bn2a_branch2b[0][0]
# __________________________________________________________________________________________________
# res2a_branch2c (Conv2D)         (None, None, None, 2 16640       activation_542[0][0]
# __________________________________________________________________________________________________
# res2a_branch1 (Conv2D)          (None, None, None, 2 16640       max_pooling2d_12[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2c (BatchNormalizati (None, None, None, 2 1024        res2a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn2a_branch1 (BatchNormalizatio (None, None, None, 2 1024        res2a_branch1[0][0]
# __________________________________________________________________________________________________
# add_177 (Add)                   (None, None, None, 2 0           bn2a_branch2c[0][0]
#                                                                  bn2a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_543 (Activation)     (None, None, None, 2 0           add_177[0][0]
# __________________________________________________________________________________________________
# res2b_branch2a (Conv2D)         (None, None, None, 6 16448       activation_543[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2a (BatchNormalizati (None, None, None, 6 256         res2b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_544 (Activation)     (None, None, None, 6 0           bn2b_branch2a[0][0]
# __________________________________________________________________________________________________
# res2b_branch2b (Conv2D)         (None, None, None, 6 36928       activation_544[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2b (BatchNormalizati (None, None, None, 6 256         res2b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_545 (Activation)     (None, None, None, 6 0           bn2b_branch2b[0][0]
# __________________________________________________________________________________________________
# res2b_branch2c (Conv2D)         (None, None, None, 2 16640       activation_545[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2c (BatchNormalizati (None, None, None, 2 1024        res2b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_178 (Add)                   (None, None, None, 2 0           bn2b_branch2c[0][0]
#                                                                  activation_543[0][0]
# __________________________________________________________________________________________________
# activation_546 (Activation)     (None, None, None, 2 0           add_178[0][0]
# __________________________________________________________________________________________________
# res2c_branch2a (Conv2D)         (None, None, None, 6 16448       activation_546[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2a (BatchNormalizati (None, None, None, 6 256         res2c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_547 (Activation)     (None, None, None, 6 0           bn2c_branch2a[0][0]
# __________________________________________________________________________________________________
# res2c_branch2b (Conv2D)         (None, None, None, 6 36928       activation_547[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2b (BatchNormalizati (None, None, None, 6 256         res2c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_548 (Activation)     (None, None, None, 6 0           bn2c_branch2b[0][0]
# __________________________________________________________________________________________________
# res2c_branch2c (Conv2D)         (None, None, None, 2 16640       activation_548[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2c (BatchNormalizati (None, None, None, 2 1024        res2c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_179 (Add)                   (None, None, None, 2 0           bn2c_branch2c[0][0]
#                                                                  activation_546[0][0]
# __________________________________________________________________________________________________
# activation_549 (Activation)     (None, None, None, 2 0           add_179[0][0]
# __________________________________________________________________________________________________
# res3a_branch2a (Conv2D)         (None, None, None, 1 32896       activation_549[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2a (BatchNormalizati (None, None, None, 1 512         res3a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_550 (Activation)     (None, None, None, 1 0           bn3a_branch2a[0][0]
# __________________________________________________________________________________________________
# res3a_branch2b (Conv2D)         (None, None, None, 1 147584      activation_550[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2b (BatchNormalizati (None, None, None, 1 512         res3a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_551 (Activation)     (None, None, None, 1 0           bn3a_branch2b[0][0]
# __________________________________________________________________________________________________
# res3a_branch2c (Conv2D)         (None, None, None, 5 66048       activation_551[0][0]
# __________________________________________________________________________________________________
# res3a_branch1 (Conv2D)          (None, None, None, 5 131584      activation_549[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2c (BatchNormalizati (None, None, None, 5 2048        res3a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn3a_branch1 (BatchNormalizatio (None, None, None, 5 2048        res3a_branch1[0][0]
# __________________________________________________________________________________________________
# add_180 (Add)                   (None, None, None, 5 0           bn3a_branch2c[0][0]
#                                                                  bn3a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_552 (Activation)     (None, None, None, 5 0           add_180[0][0]
# __________________________________________________________________________________________________
# res3b_branch2a (Conv2D)         (None, None, None, 1 65664       activation_552[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2a (BatchNormalizati (None, None, None, 1 512         res3b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_553 (Activation)     (None, None, None, 1 0           bn3b_branch2a[0][0]
# __________________________________________________________________________________________________
# res3b_branch2b (Conv2D)         (None, None, None, 1 147584      activation_553[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2b (BatchNormalizati (None, None, None, 1 512         res3b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_554 (Activation)     (None, None, None, 1 0           bn3b_branch2b[0][0]
# __________________________________________________________________________________________________
# res3b_branch2c (Conv2D)         (None, None, None, 5 66048       activation_554[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2c (BatchNormalizati (None, None, None, 5 2048        res3b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_181 (Add)                   (None, None, None, 5 0           bn3b_branch2c[0][0]
#                                                                  activation_552[0][0]
# __________________________________________________________________________________________________
# activation_555 (Activation)     (None, None, None, 5 0           add_181[0][0]
# __________________________________________________________________________________________________
# res3c_branch2a (Conv2D)         (None, None, None, 1 65664       activation_555[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2a (BatchNormalizati (None, None, None, 1 512         res3c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_556 (Activation)     (None, None, None, 1 0           bn3c_branch2a[0][0]
# __________________________________________________________________________________________________
# res3c_branch2b (Conv2D)         (None, None, None, 1 147584      activation_556[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2b (BatchNormalizati (None, None, None, 1 512         res3c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_557 (Activation)     (None, None, None, 1 0           bn3c_branch2b[0][0]
# __________________________________________________________________________________________________
# res3c_branch2c (Conv2D)         (None, None, None, 5 66048       activation_557[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2c (BatchNormalizati (None, None, None, 5 2048        res3c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_182 (Add)                   (None, None, None, 5 0           bn3c_branch2c[0][0]
#                                                                  activation_555[0][0]
# __________________________________________________________________________________________________
# activation_558 (Activation)     (None, None, None, 5 0           add_182[0][0]
# __________________________________________________________________________________________________
# res3d_branch2a (Conv2D)         (None, None, None, 1 65664       activation_558[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2a (BatchNormalizati (None, None, None, 1 512         res3d_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_559 (Activation)     (None, None, None, 1 0           bn3d_branch2a[0][0]
# __________________________________________________________________________________________________
# res3d_branch2b (Conv2D)         (None, None, None, 1 147584      activation_559[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2b (BatchNormalizati (None, None, None, 1 512         res3d_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_560 (Activation)     (None, None, None, 1 0           bn3d_branch2b[0][0]
# __________________________________________________________________________________________________
# res3d_branch2c (Conv2D)         (None, None, None, 5 66048       activation_560[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2c (BatchNormalizati (None, None, None, 5 2048        res3d_branch2c[0][0]
# __________________________________________________________________________________________________
# add_183 (Add)                   (None, None, None, 5 0           bn3d_branch2c[0][0]
#                                                                  activation_558[0][0]
# __________________________________________________________________________________________________
# activation_561 (Activation)     (None, None, None, 5 0           add_183[0][0]
# __________________________________________________________________________________________________
# res4a_branch2a (Conv2D)         (None, None, None, 2 131328      activation_561[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2a (BatchNormalizati (None, None, None, 2 1024        res4a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_562 (Activation)     (None, None, None, 2 0           bn4a_branch2a[0][0]
# __________________________________________________________________________________________________
# res4a_branch2b (Conv2D)         (None, None, None, 2 590080      activation_562[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2b (BatchNormalizati (None, None, None, 2 1024        res4a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_563 (Activation)     (None, None, None, 2 0           bn4a_branch2b[0][0]
# __________________________________________________________________________________________________
# res4a_branch2c (Conv2D)         (None, None, None, 1 263168      activation_563[0][0]
# __________________________________________________________________________________________________
# res4a_branch1 (Conv2D)          (None, None, None, 1 525312      activation_561[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2c (BatchNormalizati (None, None, None, 1 4096        res4a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn4a_branch1 (BatchNormalizatio (None, None, None, 1 4096        res4a_branch1[0][0]
# __________________________________________________________________________________________________
# add_184 (Add)                   (None, None, None, 1 0           bn4a_branch2c[0][0]
#                                                                  bn4a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_564 (Activation)     (None, None, None, 1 0           add_184[0][0]
# __________________________________________________________________________________________________
# res4b_branch2a (Conv2D)         (None, None, None, 2 262400      activation_564[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2a (BatchNormalizati (None, None, None, 2 1024        res4b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_565 (Activation)     (None, None, None, 2 0           bn4b_branch2a[0][0]
# __________________________________________________________________________________________________
# res4b_branch2b (Conv2D)         (None, None, None, 2 590080      activation_565[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2b (BatchNormalizati (None, None, None, 2 1024        res4b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_566 (Activation)     (None, None, None, 2 0           bn4b_branch2b[0][0]
# __________________________________________________________________________________________________
# res4b_branch2c (Conv2D)         (None, None, None, 1 263168      activation_566[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2c (BatchNormalizati (None, None, None, 1 4096        res4b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_185 (Add)                   (None, None, None, 1 0           bn4b_branch2c[0][0]
#                                                                  activation_564[0][0]
# __________________________________________________________________________________________________
# activation_567 (Activation)     (None, None, None, 1 0           add_185[0][0]
# __________________________________________________________________________________________________
# res4c_branch2a (Conv2D)         (None, None, None, 2 262400      activation_567[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2a (BatchNormalizati (None, None, None, 2 1024        res4c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_568 (Activation)     (None, None, None, 2 0           bn4c_branch2a[0][0]
# __________________________________________________________________________________________________
# res4c_branch2b (Conv2D)         (None, None, None, 2 590080      activation_568[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2b (BatchNormalizati (None, None, None, 2 1024        res4c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_569 (Activation)     (None, None, None, 2 0           bn4c_branch2b[0][0]
# __________________________________________________________________________________________________
# res4c_branch2c (Conv2D)         (None, None, None, 1 263168      activation_569[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2c (BatchNormalizati (None, None, None, 1 4096        res4c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_186 (Add)                   (None, None, None, 1 0           bn4c_branch2c[0][0]
#                                                                  activation_567[0][0]
# __________________________________________________________________________________________________
# activation_570 (Activation)     (None, None, None, 1 0           add_186[0][0]
# __________________________________________________________________________________________________
# res4d_branch2a (Conv2D)         (None, None, None, 2 262400      activation_570[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2a (BatchNormalizati (None, None, None, 2 1024        res4d_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_571 (Activation)     (None, None, None, 2 0           bn4d_branch2a[0][0]
# __________________________________________________________________________________________________
# res4d_branch2b (Conv2D)         (None, None, None, 2 590080      activation_571[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2b (BatchNormalizati (None, None, None, 2 1024        res4d_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_572 (Activation)     (None, None, None, 2 0           bn4d_branch2b[0][0]
# __________________________________________________________________________________________________
# res4d_branch2c (Conv2D)         (None, None, None, 1 263168      activation_572[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2c (BatchNormalizati (None, None, None, 1 4096        res4d_branch2c[0][0]
# __________________________________________________________________________________________________
# add_187 (Add)                   (None, None, None, 1 0           bn4d_branch2c[0][0]
#                                                                  activation_570[0][0]
# __________________________________________________________________________________________________
# activation_573 (Activation)     (None, None, None, 1 0           add_187[0][0]
# __________________________________________________________________________________________________
# res4e_branch2a (Conv2D)         (None, None, None, 2 262400      activation_573[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2a (BatchNormalizati (None, None, None, 2 1024        res4e_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_574 (Activation)     (None, None, None, 2 0           bn4e_branch2a[0][0]
# __________________________________________________________________________________________________
# res4e_branch2b (Conv2D)         (None, None, None, 2 590080      activation_574[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2b (BatchNormalizati (None, None, None, 2 1024        res4e_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_575 (Activation)     (None, None, None, 2 0           bn4e_branch2b[0][0]
# __________________________________________________________________________________________________
# res4e_branch2c (Conv2D)         (None, None, None, 1 263168      activation_575[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2c (BatchNormalizati (None, None, None, 1 4096        res4e_branch2c[0][0]
# __________________________________________________________________________________________________
# add_188 (Add)                   (None, None, None, 1 0           bn4e_branch2c[0][0]
#                                                                  activation_573[0][0]
# __________________________________________________________________________________________________
# activation_576 (Activation)     (None, None, None, 1 0           add_188[0][0]
# __________________________________________________________________________________________________
# res4f_branch2a (Conv2D)         (None, None, None, 2 262400      activation_576[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2a (BatchNormalizati (None, None, None, 2 1024        res4f_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_577 (Activation)     (None, None, None, 2 0           bn4f_branch2a[0][0]
# __________________________________________________________________________________________________
# res4f_branch2b (Conv2D)         (None, None, None, 2 590080      activation_577[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2b (BatchNormalizati (None, None, None, 2 1024        res4f_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_578 (Activation)     (None, None, None, 2 0           bn4f_branch2b[0][0]
# __________________________________________________________________________________________________
# res4f_branch2c (Conv2D)         (None, None, None, 1 263168      activation_578[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2c (BatchNormalizati (None, None, None, 1 4096        res4f_branch2c[0][0]
# __________________________________________________________________________________________________
# add_189 (Add)                   (None, None, None, 1 0           bn4f_branch2c[0][0]
#                                                                  activation_576[0][0]
# __________________________________________________________________________________________________
# activation_579 (Activation)     (None, None, None, 1 0           add_189[0][0]
# __________________________________________________________________________________________________
# res5a_branch2a (Conv2D)         (None, None, None, 5 524800      activation_579[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2a (BatchNormalizati (None, None, None, 5 2048        res5a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_580 (Activation)     (None, None, None, 5 0           bn5a_branch2a[0][0]
# __________________________________________________________________________________________________
# res5a_branch2b (Conv2D)         (None, None, None, 5 2359808     activation_580[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2b (BatchNormalizati (None, None, None, 5 2048        res5a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_581 (Activation)     (None, None, None, 5 0           bn5a_branch2b[0][0]
# __________________________________________________________________________________________________
# res5a_branch2c (Conv2D)         (None, None, None, 2 1050624     activation_581[0][0]
# __________________________________________________________________________________________________
# res5a_branch1 (Conv2D)          (None, None, None, 2 2099200     activation_579[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2c (BatchNormalizati (None, None, None, 2 8192        res5a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn5a_branch1 (BatchNormalizatio (None, None, None, 2 8192        res5a_branch1[0][0]
# __________________________________________________________________________________________________
# add_190 (Add)                   (None, None, None, 2 0           bn5a_branch2c[0][0]
#                                                                  bn5a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_582 (Activation)     (None, None, None, 2 0           add_190[0][0]
# __________________________________________________________________________________________________
# res5b_branch2a (Conv2D)         (None, None, None, 5 1049088     activation_582[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2a (BatchNormalizati (None, None, None, 5 2048        res5b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_583 (Activation)     (None, None, None, 5 0           bn5b_branch2a[0][0]
# __________________________________________________________________________________________________
# res5b_branch2b (Conv2D)         (None, None, None, 5 2359808     activation_583[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2b (BatchNormalizati (None, None, None, 5 2048        res5b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_584 (Activation)     (None, None, None, 5 0           bn5b_branch2b[0][0]
# __________________________________________________________________________________________________
# res5b_branch2c (Conv2D)         (None, None, None, 2 1050624     activation_584[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2c (BatchNormalizati (None, None, None, 2 8192        res5b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_191 (Add)                   (None, None, None, 2 0           bn5b_branch2c[0][0]
#                                                                  activation_582[0][0]
# __________________________________________________________________________________________________
# activation_585 (Activation)     (None, None, None, 2 0           add_191[0][0]
# __________________________________________________________________________________________________
# res5c_branch2a (Conv2D)         (None, None, None, 5 1049088     activation_585[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2a (BatchNormalizati (None, None, None, 5 2048        res5c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_586 (Activation)     (None, None, None, 5 0           bn5c_branch2a[0][0]
# __________________________________________________________________________________________________
# res5c_branch2b (Conv2D)         (None, None, None, 5 2359808     activation_586[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2b (BatchNormalizati (None, None, None, 5 2048        res5c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_587 (Activation)     (None, None, None, 5 0           bn5c_branch2b[0][0]
# __________________________________________________________________________________________________
# res5c_branch2c (Conv2D)         (None, None, None, 2 1050624     activation_587[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2c (BatchNormalizati (None, None, None, 2 8192        res5c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_192 (Add)                   (None, None, None, 2 0           bn5c_branch2c[0][0]
#                                                                  activation_585[0][0]
# __________________________________________________________________________________________________
# activation_588 (Activation)     (None, None, None, 2 0           add_192[0][0]
# __________________________________________________________________________________________________
# avg_pool (AveragePooling2D)     (None, None, None, 2 0           activation_588[0][0]
# __________________________________________________________________________________________________
# global_max_pooling2d_12 (Global (None, 2048)         0           avg_pool[0][0]
# __________________________________________________________________________________________________
# dropout_12 (Dropout)            (None, 2048)         0           global_max_pooling2d_12[0][0]
# __________________________________________________________________________________________________
# dense_12 (Dense)                (None, 256)          524544      dropout_12[0][0]
# __________________________________________________________________________________________________
# lambda_12 (Lambda)              (None, 256)          0           dense_12[0][0]
# ==================================================================================================
# Total params: 24,112,256
# Trainable params: 24,059,136
# Non-trainable params: 53,120
# __________________________________________________________________________________________________
# None

# %%
# 这里用欧式距离判断class id，并且选取了6个neighbors
neigh = NearestNeighbors(n_neighbors=6)
neigh.fit(train_preds)
#distances, neighbors = neigh.kneighbors(train_preds)

#print(distances, neighbors)

# 对每个test样本，返回最近的六个embeddings,注意neighbors_test是train_preds里面样本的Index，而非样本本身
distances_test, neighbors_test = neigh.kneighbors(test_preds)

distances_test, neighbors_test = distances_test.tolist(), neighbors_test.tolist()

preds_str = []

for filepath, distance, neighbour_ in zip(test_file_names, distances_test, neighbors_test):
    sample_result = []
    sample_classes = []
    for d, n in zip(distance, neighbour_):
        train_file = train_files[n].split(os.sep)[-1]
        class_train = file_id_mapping[train_file]
        sample_classes.append(class_train)
        sample_result.append((class_train, d))

    if "new_whale" not in sample_classes:
        sample_result.append(("new_whale", 0.09))#new_whale有大概率出现，距离设置为0.1
    sample_result.sort(key=lambda x: x[1])
    sample_result = sample_result[:5] #取前五个距离最小的预测值
    preds_str.append(" ".join([x[0] for x in sample_result]))

df = pd.DataFrame(preds_str, columns=["Id"])
df['Image'] = [x.split(os.sep)[-1] for x in test_file_names]
df.to_csv("sub_%s.csv"%model_name, index=False)

# %%
# check the distance range
# 如何选择new_whale对应的距离值？  why 0.1 ？？？？
test_preds_parts = test_preds[:10]
distances_test, neighbors_test = neigh.kneighbors(test_preds_parts)
print distances_test
# Out:
# [[0.08126209 0.08126209 0.08186337 0.08216192 0.08413878 0.08443262]
#  [0.10770522 0.10879348 0.11002699 0.118119   0.11852136 0.12149963]
#  [0.         0.17586181 0.17881008 0.1869628  0.19458691 0.19706372]
#  [0.18991647 0.19711524 0.19720327 0.19731364 0.19800723 0.20047218]
#  [0.17595036 0.17924069 0.18244697 0.18247241 0.18358763 0.1843859 ]
#  [0.05163546 0.05667249 0.05690539 0.05814614 0.05902657 0.05960685]
#  [0.17996753 0.18226758 0.18281613 0.18805499 0.19108193 0.19247563]
#  [0.09034755 0.09096052 0.09157771 0.09173478 0.0926957  0.09283236]
#  [0.12068342 0.12173704 0.12741168 0.12850561 0.1286524  0.1286524 ]
#  [0.09132574 0.09284253 0.09408153 0.09426448 0.09444214 0.09456885]]
