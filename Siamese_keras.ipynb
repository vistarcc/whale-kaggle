# %% [markdown]
# # Read me
#
# To run on multi-GPU server, please:
#
# [1]increase data_size to a larger number (say 100000):
#
# generate_image_pair_and_labels(X_imgs, labels_dataframe['labels'].tolist(), data_size=100)
#
# [2]increase image size if necessary (say 224):
#
# IMAGE_SIZE = 128
#
# [3]increase GPU numbers, 1 is default:
#
# G = 1 #the number of GPU
#
# [4]increase epochs (say 1000):
#
# n_epochs = 30
#
# [5]increae batch size if you have large GPU memory (say 64):
#
# batch_size = 10

# %%
import tensorflow as tf
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from PIL import Image
import matplotlib.gridspec as gridspec
import numpy as np
import os
import cv2
import pandas as pd
from math import floor, ceil, pi

# %matplotlib inline

# %% [markdown]
# # Load raw images

# %%
def get_image_paths():
    folder = './data/whale/train_full'
    files = os.listdir(folder)
    files.sort()
    files = ['{}/{}'.format(folder, file) for file in files]
    return files

X_img_paths = get_image_paths()
print(X_img_paths[:20])
# Out:
# ['./data/whale/train_full/00022e1a.jpg', './data/whale/train_full/000466c4.jpg', './data/whale/train_full/00087b01.jpg', './data/whale/train_full/001296d5.jpg', './data/whale/train_full/0014cfdf.jpg', './data/whale/train_full/0025e8c2.jpg', './data/whale/train_full/0026a8ab.jpg', './data/whale/train_full/0031c258.jpg', './data/whale/train_full/0035632e.jpg', './data/whale/train_full/0037e7d3.jpg', './data/whale/train_full/00389cd7.jpg', './data/whale/train_full/0042dcc4.jpg', './data/whale/train_full/0042ea34.jpg', './data/whale/train_full/00467ae9.jpg', './data/whale/train_full/004a97f3.jpg', './data/whale/train_full/004c5fb9.jpg', './data/whale/train_full/005c57e7.jpg', './data/whale/train_full/006d0aaf.jpg', './data/whale/train_full/0078af23.jpg', './data/whale/train_full/007c3603.jpg']

# %% [markdown]
# # Load whale ids

# %%
def load_labels():
    csv_file = './data/whale/train.csv'
    data_labels = pd.read_csv(csv_file)
    return data_labels

data_labels = load_labels()
data_labels.head()
# Out:
#           Image         Id
# 0  00022e1a.jpg  w_e15442c
# 1  000466c4.jpg  w_1287fbc
# 2  00087b01.jpg  w_da2efe0
# 3  001296d5.jpg  w_19e5482
# 4  0014cfdf.jpg  w_f22f3e3

# %% [markdown]
# # Id analysis

# %%
data_labels['Id'].value_counts()

# %% [markdown]
# # select ids occur more than 4 times

# %%
def get_label_subset_by_threshold(occurence=5):
    value_statics = data_labels['Id'].value_counts()
    value_cut = value_statics[value_statics >= occurence]
    value_cut = value_cut[value_cut < 100] #remove the "new whale" type
    return value_cut  #return type: pandas series

label_subset = get_label_subset_by_threshold(occurence=5)

# %% [markdown]
# # Data augmentation: to do

# %%
def data_augmentation(original_image):
    #to do
    
    return original_image

# %%
def is_include_subset(label, label_subset):
    if label in label_subset.index:
        return True
    else:
        return False
    
def rgb2gray(rgb):
    return np.dot(rgb[...,:3], [0.299, 0.587, 0.114])

# %% [markdown]
# # image resize and augmentation

# %%
IMAGE_SIZE = 128

def tf_resize_augment_images(X_img_file_paths):
    X_data = []
    y_data = []
    tf.reset_default_graph()
    X = tf.placeholder(tf.float32, (None, None, 1))
    tf_img = tf.image.resize_images(X, (IMAGE_SIZE, IMAGE_SIZE), tf.image.ResizeMethod.NEAREST_NEIGHBOR)
    with tf.Session() as sess:
        sess.run(tf.global_variables_initializer())
        
        # Each image is resized individually as different image may be of different size.
        for index, file_path in enumerate(X_img_file_paths):
            label = data_labels.iloc[index]['Id']
            
            if is_include_subset(label, label_subset):
                img = mpimg.imread(file_path)
                if len(img.shape) > 2:# convert to grayscale
                    img = rgb2gray(img)
                img = img.reshape(img.shape[0], img.shape[1], 1)
                resized_img = sess.run(tf_img, feed_dict = {X: img})
                X_data.append(data_augmentation(resized_img))
                y_data.append(label)

    X_data = np.array(X_data, dtype = np.float32) # Convert to numpy
    return X_data, y_data

X_imgs, y_data = tf_resize_augment_images(X_img_paths)
print(X_imgs.shape)

# %% [markdown]
# # image nromalization

# %%
def image_normalize(images):
    
    return images

# %% [markdown]
# # save processed images and labels

# %%
np.save('./data/whale/save/resize.npy', X_imgs)
labels_dataframe = pd.DataFrame({'labels':y_data})
labels_dataframe.to_csv('./data/whale/save/labels.csv', index=False)

# %% [markdown]
# # load data

# %%
X_imgs = np.load('./data/whale/save/resize.npy')
labels_dataframe = pd.read_csv('./data/whale/save/labels.csv')
labels_dataframe.head()
# Out:
#       labels
# 0  w_1287fbc
# 1  w_da2efe0
# 2  w_3d0bc7a
# 3  w_fd1cb9d
# 4  w_ab6db0f

# %% [markdown]
# # generate image pairs and labels(true or false)

# %%
import tensorflow as tf
import numpy as np

# %%
def generate_image_pair_and_labels(images, labels, data_size=500):
    size1 = data_size // 2 
    size2 = data_size - size1
    if size1 < size2 and np.random.rand() > 0.5:
        size1, size2 = size2, size1
    
    X, y = [], []
    k = 0
    while k < size1:
        idx1, idx2 = np.random.randint(0, len(labels), 2)
        if idx1 != idx2 and labels[idx1] == labels[idx2]:
            X.append(np.array([images[idx1], images[idx2]]))
            y.append([1])
            k += 1
    k = 0
    while k < size2:
        idx1, idx2 = np.random.randint(0, len(labels), 2)
        if labels[idx1] != labels[idx2]:
            X.append(np.array([images[idx1], images[idx2]]))
            y.append([0])
            k += 1
            
    shuffled_idx = np.random.permutation(data_size)
    return np.array(X)[shuffled_idx], np.array(y)[shuffled_idx]

#select 100 pairs to tain siamese network, just for quick test
image_pairs, y_labels = generate_image_pair_and_labels(X_imgs, labels_dataframe['labels'].tolist(), data_size=10000)

# %% [markdown]
# # split data

# %%
test_ratio = 0.3
image_pair_train = image_pairs[:int((1 - test_ratio) * len(y_labels))]
y_labels_train = y_labels[:int((1 - test_ratio) * len(y_labels))]
image_pair_test = image_pairs[int((1 - test_ratio) * len(y_labels)):]
y_labels_test = y_labels[int((1 - test_ratio) * len(y_labels)):]

# %%
from keras.layers import Input, Conv2D, Lambda, subtract, merge, Dense, Flatten, MaxPooling2D, BatchNormalization, LeakyReLU, Activation, add
from keras.models import Model, Sequential
from keras.regularizers import l2
from keras import backend as K
from keras.optimizers import SGD,Adam
from keras.losses import binary_crossentropy
from keras.utils.training_utils import multi_gpu_model

K.clear_session()
tf.reset_default_graph()

# %% [markdown]
# # define residual network block

# %%
def resNet_block(image1, image2, channel, strides):
    conv1 = Conv2D(channel, kernel_size=(3, 3), strides=(strides, strides), kernel_initializer="he_normal", padding='same')
#   batch normalization parameters are not reused  
    bn1 = BatchNormalization()
    bn2 = BatchNormalization()
    rl1 = Activation('relu') 
    conv2 = Conv2D(channel, kernel_size=(3, 3), strides=(1, 1), kernel_initializer="he_normal", padding='same')

    #reuse weights & bias within block
    net1 = conv2(rl1(bn1(conv1(image1))))
    net2 = conv2(rl1(bn2(conv1(image2))))
    
    if strides > 1:
        conv3 = Conv2D(channel, kernel_size=(3, 3), strides=(strides, strides), kernel_initializer="he_normal", padding='same')
        image1 = conv3(image1)
        image2 = conv3(image2)
        
    net1 = add([image1, net1])
    net2 = add([image2, net2])
    bn3 = BatchNormalization()
    bn4 = BatchNormalization()
    rl2 = Activation('relu')
    
    return rl2(bn3(net1)), rl2(bn4(net2))

# %% [markdown]
# # define residual network

# %%
def residual_network(image1, image2):
    conv1 = Conv2D(32, kernel_size=(7, 7), strides=(2, 2), kernel_initializer="he_normal", padding='same')
    bn1 = BatchNormalization()
    bn2 = BatchNormalization()
    rl1 = Activation('relu')  
    mp1 = MaxPooling2D()
    
    net1, net2 = mp1(rl1(bn1(conv1(image1)))), mp1(rl1(bn2(conv1(image2))))
    
    net1, net2 = resNet_block(net1, net2, 32, 1)
    net1, net2 = resNet_block(net1, net2, 32, 1)
    net1, net2 = resNet_block(net1, net2, 32, 1)
    net1, net2 = resNet_block(net1, net2, 64, 2)
    net1, net2 = resNet_block(net1, net2, 64, 1)
    net1, net2 = resNet_block(net1, net2, 64, 1)
    net1, net2 = resNet_block(net1, net2, 128, 2)
    net1, net2 = resNet_block(net1, net2, 128, 1)
    net1, net2 = resNet_block(net1, net2, 128, 1)
    
    mp2 = MaxPooling2D()
    flatten1 = Flatten()
    
    return flatten1(mp2(net1)), flatten1(mp2(net2))

# %% [markdown]
# # define siamese netwrok

# %%
learning_rate = 0.00001
input_shape = (2, IMAGE_SIZE, IMAGE_SIZE, 1)
inputs = Input(input_shape)
G = 1 #the number of GPU

# %%
def siamese_network(image_pairs):
    # not support tf.ops in keras, fk!!!!
#     image1, image2 = tf.unstack(image_pairs, axis=1)
    image1 = Lambda(lambda x : x[:,0,:,:])(image_pairs)
    image2 = Lambda(lambda x : x[:,1,:,:])(image_pairs)

    embedding1, embedding2 = residual_network(image1, image2)
    
    #merge two encoded inputs with the l1 distance between them
#     subtracted = subtract([embedding1, embedding2])
#     both1 = K.abs(subtracted)
#     print type(both1)
    
    L1_distance = lambda x: K.abs(x[0]-x[1])
    both = merge([embedding1,embedding2], mode = L1_distance, output_shape=lambda x: x[0])
    print type(both)
    
    prediction = Dense(1, activation='sigmoid', kernel_initializer='he_normal')(both)
    
    # check to see if we are compiling using just a single GPU
    if G <= 1:
        print("[INFO] training with 1 GPU...")
        siamese_net = Model(input=image_pairs, output=prediction)
    # otherwise, we are compiling using multiple GPUs
    else:
        print("[INFO] training with {} GPUs...".format(G))

        # we'll store a copy of the model on *every* GPU and then combine
        # the results from the gradient updates on the CPU
        with tf.device("/cpu:0"):
            # initialize the model
            siamese_net = Model(input=image_pairs, output=prediction)

        # make the model parallel
        siamese_net = multi_gpu_model(siamese_net, gpus=G)    
    
    optimizer = Adam(learning_rate)
    siamese_net.compile(loss="binary_crossentropy",optimizer=optimizer, metrics=['accuracy'])
    
    return siamese_net

siamese_net = siamese_network(inputs)
# Out:
# <class 'tensorflow.python.framework.ops.Tensor'>
# [INFO] training with 1 GPU...
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:15: UserWarning: The `merge` function is deprecated and will be removed after 08/2017. Use instead layers from `keras.layers.merge`, e.g. `add`, `concatenate`, etc.
#   from ipykernel import kernelapp as app
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:23: UserWarning: Update your `Model` call to the Keras 2 API: `Model(outputs=Tensor("de..., inputs=Tensor("in...)`

# %% [markdown]
# # start training

# %%
n_epochs = 500
batch_size = 20
n_batches = len(y_labels_train) // batch_size

for epoch in range(n_epochs):    
    idx = np.random.permutation(len(y_labels_train))
    X_batches = np.array_split(image_pair_train[idx], n_batches)
    y_batches = np.array_split(y_labels_train[idx], n_batches)

    for X_batch, y_batch in zip(X_batches, y_batches):
        loss_train, acc_train = siamese_net.train_on_batch(X_batch,y_batch)

    loss_test, acc_test = siamese_net.evaluate(x=image_pair_test, y=y_labels_test, batch_size=batch_size, verbose=0)
    
    print "epoch:{}\tloss_train:{:.7f}\tloss_test:{:.7f}\tacc_train:{:.2f}%\tacc_test:{:.2f}%".format(
        epoch, loss_train, loss_test, acc_train*100, acc_test*100)
# Out:
# epoch:0	loss_train:0.533	loss_test:0.682	acc_train:85.00%	acc_test:62.10%
# epoch:1	loss_train:0.399	loss_test:0.688	acc_train:90.00%	acc_test:62.50%
# epoch:2	loss_train:0.422	loss_test:0.673	acc_train:90.00%	acc_test:63.80%
# epoch:3	loss_train:0.533	loss_test:0.677	acc_train:75.00%	acc_test:63.43%
# epoch:4	loss_train:0.505	loss_test:0.676	acc_train:80.00%	acc_test:64.10%
# epoch:5	loss_train:0.445	loss_test:0.677	acc_train:80.00%	acc_test:64.73%
# epoch:6	loss_train:0.526	loss_test:0.679	acc_train:75.00%	acc_test:64.07%
# epoch:7	loss_train:0.443	loss_test:0.679	acc_train:85.00%	acc_test:65.20%
# epoch:8	loss_train:0.469	loss_test:0.682	acc_train:80.00%	acc_test:64.43%
# epoch:9	loss_train:0.306	loss_test:0.682	acc_train:100.00%	acc_test:64.83%
# epoch:10	loss_train:0.399	loss_test:0.679	acc_train:90.00%	acc_test:64.77%
# epoch:11	loss_train:0.365	loss_test:0.685	acc_train:80.00%	acc_test:64.97%
# epoch:12	loss_train:0.385	loss_test:0.685	acc_train:85.00%	acc_test:65.20%
# epoch:13	loss_train:0.236	loss_test:0.686	acc_train:100.00%	acc_test:64.43%
# epoch:14	loss_train:0.267	loss_test:0.693	acc_train:95.00%	acc_test:64.73%
# epoch:15	loss_train:0.255	loss_test:0.690	acc_train:95.00%	acc_test:65.30%
# epoch:16	loss_train:0.255	loss_test:0.687	acc_train:90.00%	acc_test:65.47%
# epoch:17	loss_train:0.350	loss_test:0.693	acc_train:90.00%	acc_test:65.83%
# epoch:18	loss_train:0.403	loss_test:0.696	acc_train:85.00%	acc_test:65.93%
# epoch:19	loss_train:0.337	loss_test:0.696	acc_train:90.00%	acc_test:66.33%
# epoch:20	loss_train:0.367	loss_test:0.698	acc_train:95.00%	acc_test:66.77%
# epoch:21	loss_train:0.136	loss_test:0.697	acc_train:100.00%	acc_test:66.90%
# epoch:22	loss_train:0.349	loss_test:0.700	acc_train:85.00%	acc_test:66.97%
# epoch:23	loss_train:0.322	loss_test:0.703	acc_train:90.00%	acc_test:66.87%
# epoch:24	loss_train:0.165	loss_test:0.705	acc_train:95.00%	acc_test:66.43%
# epoch:25	loss_train:0.253	loss_test:0.707	acc_train:95.00%	acc_test:66.43%
# epoch:26	loss_train:0.216	loss_test:0.709	acc_train:90.00%	acc_test:66.70%
# epoch:27	loss_train:0.183	loss_test:0.712	acc_train:95.00%	acc_test:67.13%
# epoch:28	loss_train:0.175	loss_test:0.718	acc_train:95.00%	acc_test:67.23%
# epoch:29	loss_train:0.197	loss_test:0.716	acc_train:90.00%	acc_test:66.77%
# epoch:30	loss_train:0.186	loss_test:0.720	acc_train:100.00%	acc_test:67.60%
# epoch:31	loss_train:0.143	loss_test:0.722	acc_train:100.00%	acc_test:67.30%
# epoch:32	loss_train:0.194	loss_test:0.726	acc_train:100.00%	acc_test:67.80%
# epoch:33	loss_train:0.212	loss_test:0.735	acc_train:95.00%	acc_test:67.03%
# epoch:34	loss_train:0.267	loss_test:0.736	acc_train:95.00%	acc_test:67.27%
# epoch:35	loss_train:0.154	loss_test:0.732	acc_train:100.00%	acc_test:67.53%
# epoch:36	loss_train:0.135	loss_test:0.742	acc_train:100.00%	acc_test:67.20%
# epoch:37	loss_train:0.091	loss_test:0.735	acc_train:100.00%	acc_test:67.87%
# epoch:38	loss_train:0.172	loss_test:0.748	acc_train:100.00%	acc_test:66.87%
# epoch:39	loss_train:0.109	loss_test:0.744	acc_train:100.00%	acc_test:67.57%
# epoch:40	loss_train:0.116	loss_test:0.748	acc_train:100.00%	acc_test:67.50%
# epoch:41	loss_train:0.223	loss_test:0.756	acc_train:90.00%	acc_test:67.97%
# epoch:42	loss_train:0.204	loss_test:0.759	acc_train:100.00%	acc_test:67.70%
# epoch:43	loss_train:0.105	loss_test:0.769	acc_train:100.00%	acc_test:67.27%
# epoch:44	loss_train:0.114	loss_test:0.766	acc_train:100.00%	acc_test:67.40%
# epoch:45	loss_train:0.087	loss_test:0.761	acc_train:100.00%	acc_test:67.60%
# epoch:46	loss_train:0.070	loss_test:0.766	acc_train:100.00%	acc_test:68.03%
# epoch:47	loss_train:0.135	loss_test:0.774	acc_train:100.00%	acc_test:67.33%
# epoch:48	loss_train:0.086	loss_test:0.777	acc_train:100.00%	acc_test:68.47%
# epoch:49	loss_train:0.177	loss_test:0.781	acc_train:90.00%	acc_test:67.97%
# epoch:50	loss_train:0.075	loss_test:0.784	acc_train:100.00%	acc_test:68.20%
# epoch:51	loss_train:0.094	loss_test:0.777	acc_train:100.00%	acc_test:68.30%
# epoch:52	loss_train:0.072	loss_test:0.793	acc_train:100.00%	acc_test:67.83%
# epoch:53	loss_train:0.100	loss_test:0.791	acc_train:100.00%	acc_test:68.10%
# epoch:54	loss_train:0.053	loss_test:0.798	acc_train:100.00%	acc_test:68.13%
# epoch:55	loss_train:0.121	loss_test:0.797	acc_train:100.00%	acc_test:68.27%
# epoch:56	loss_train:0.024	loss_test:0.803	acc_train:100.00%	acc_test:68.30%
# epoch:57	loss_train:0.046	loss_test:0.813	acc_train:100.00%	acc_test:67.90%
# epoch:58	loss_train:0.048	loss_test:0.808	acc_train:100.00%	acc_test:68.23%
# epoch:59	loss_train:0.049	loss_test:0.814	acc_train:100.00%	acc_test:68.43%
# epoch:60	loss_train:0.050	loss_test:0.815	acc_train:100.00%	acc_test:68.63%
# epoch:61	loss_train:0.060	loss_test:0.822	acc_train:100.00%	acc_test:68.30%
# epoch:62	loss_train:0.053	loss_test:0.824	acc_train:100.00%	acc_test:68.23%
# epoch:63	loss_train:0.032	loss_test:0.828	acc_train:100.00%	acc_test:68.70%
# epoch:64	loss_train:0.102	loss_test:0.836	acc_train:100.00%	acc_test:68.43%
# epoch:65	loss_train:0.028	loss_test:0.847	acc_train:100.00%	acc_test:68.37%
# epoch:66	loss_train:0.014	loss_test:0.850	acc_train:100.00%	acc_test:67.70%
# epoch:67	loss_train:0.049	loss_test:0.852	acc_train:100.00%	acc_test:68.30%
# epoch:68	loss_train:0.091	loss_test:0.851	acc_train:100.00%	acc_test:68.53%
# epoch:69	loss_train:0.026	loss_test:0.848	acc_train:100.00%	acc_test:68.63%
# epoch:70	loss_train:0.016	loss_test:0.847	acc_train:100.00%	acc_test:69.23%
# epoch:71	loss_train:0.042	loss_test:0.858	acc_train:100.00%	acc_test:68.83%
# epoch:72	loss_train:0.047	loss_test:0.864	acc_train:100.00%	acc_test:68.47%
# epoch:73	loss_train:0.026	loss_test:0.881	acc_train:100.00%	acc_test:68.63%
# epoch:74	loss_train:0.081	loss_test:0.872	acc_train:100.00%	acc_test:69.03%
# epoch:75	loss_train:0.055	loss_test:0.868	acc_train:100.00%	acc_test:69.10%
# epoch:76	loss_train:0.033	loss_test:0.879	acc_train:100.00%	acc_test:68.77%
# epoch:77	loss_train:0.016	loss_test:0.890	acc_train:100.00%	acc_test:68.93%
# epoch:78	loss_train:0.012	loss_test:0.889	acc_train:100.00%	acc_test:68.93%
# epoch:79	loss_train:0.023	loss_test:0.892	acc_train:100.00%	acc_test:68.83%
# epoch:80	loss_train:0.008	loss_test:0.892	acc_train:100.00%	acc_test:68.87%
# epoch:81	loss_train:0.014	loss_test:0.909	acc_train:100.00%	acc_test:68.53%
# epoch:82	loss_train:0.016	loss_test:0.903	acc_train:100.00%	acc_test:68.73%
# epoch:83	loss_train:0.030	loss_test:0.903	acc_train:100.00%	acc_test:69.07%
# epoch:84	loss_train:0.015	loss_test:0.896	acc_train:100.00%	acc_test:69.07%
# epoch:85	loss_train:0.011	loss_test:0.906	acc_train:100.00%	acc_test:68.73%
# epoch:86	loss_train:0.016	loss_test:0.907	acc_train:100.00%	acc_test:69.07%
# epoch:87	loss_train:0.019	loss_test:0.919	acc_train:100.00%	acc_test:69.10%
# epoch:88	loss_train:0.010	loss_test:0.921	acc_train:100.00%	acc_test:69.60%
# epoch:89	loss_train:0.008	loss_test:0.910	acc_train:100.00%	acc_test:69.53%
# epoch:90	loss_train:0.017	loss_test:0.920	acc_train:100.00%	acc_test:68.80%
# epoch:91	loss_train:0.007	loss_test:0.935	acc_train:100.00%	acc_test:68.93%
# epoch:92	loss_train:0.009	loss_test:0.939	acc_train:100.00%	acc_test:68.87%
# epoch:93	loss_train:0.004	loss_test:0.944	acc_train:100.00%	acc_test:68.43%
# epoch:94	loss_train:0.023	loss_test:0.945	acc_train:100.00%	acc_test:68.97%
# epoch:95	loss_train:0.017	loss_test:0.941	acc_train:100.00%	acc_test:69.03%
# epoch:96	loss_train:0.021	loss_test:0.946	acc_train:100.00%	acc_test:69.40%
# epoch:97	loss_train:0.007	loss_test:0.955	acc_train:100.00%	acc_test:68.97%
# epoch:98	loss_train:0.007	loss_test:0.962	acc_train:100.00%	acc_test:68.80%
# epoch:99	loss_train:0.012	loss_test:0.966	acc_train:100.00%	acc_test:69.03%
# epoch:100	loss_train:0.010	loss_test:0.968	acc_train:100.00%	acc_test:69.70%
# epoch:101	loss_train:0.025	loss_test:0.966	acc_train:100.00%	acc_test:69.67%
# epoch:102	loss_train:0.007	loss_test:0.975	acc_train:100.00%	acc_test:69.07%
# epoch:103	loss_train:0.020	loss_test:0.970	acc_train:100.00%	acc_test:69.53%
# epoch:104	loss_train:0.011	loss_test:0.985	acc_train:100.00%	acc_test:68.93%
# epoch:105	loss_train:0.002	loss_test:0.991	acc_train:100.00%	acc_test:69.10%
# epoch:106	loss_train:0.023	loss_test:0.993	acc_train:100.00%	acc_test:69.17%
# epoch:107	loss_train:0.004	loss_test:0.995	acc_train:100.00%	acc_test:69.23%
# epoch:108	loss_train:0.006	loss_test:1.002	acc_train:100.00%	acc_test:69.10%
# epoch:109	loss_train:0.009	loss_test:0.997	acc_train:100.00%	acc_test:69.13%
# epoch:110	loss_train:0.019	loss_test:1.005	acc_train:100.00%	acc_test:69.80%
# epoch:111	loss_train:0.002	loss_test:1.009	acc_train:100.00%	acc_test:69.47%
# epoch:112	loss_train:0.005	loss_test:0.999	acc_train:100.00%	acc_test:69.90%
# epoch:113	loss_train:0.003	loss_test:1.007	acc_train:100.00%	acc_test:69.87%
# epoch:114	loss_train:0.004	loss_test:1.016	acc_train:100.00%	acc_test:69.87%
# epoch:115	loss_train:0.003	loss_test:1.014	acc_train:100.00%	acc_test:69.10%
# epoch:116	loss_train:0.002	loss_test:1.010	acc_train:100.00%	acc_test:69.57%
# epoch:117	loss_train:0.004	loss_test:1.027	acc_train:100.00%	acc_test:69.17%
# epoch:118	loss_train:0.018	loss_test:1.019	acc_train:100.00%	acc_test:69.93%
# epoch:119	loss_train:0.002	loss_test:1.030	acc_train:100.00%	acc_test:69.73%
# epoch:120	loss_train:0.002	loss_test:1.037	acc_train:100.00%	acc_test:70.10%
# epoch:121	loss_train:0.001	loss_test:1.031	acc_train:100.00%	acc_test:69.63%
# epoch:122	loss_train:0.002	loss_test:1.043	acc_train:100.00%	acc_test:69.07%
# epoch:123	loss_train:0.003	loss_test:1.043	acc_train:100.00%	acc_test:69.97%
# epoch:124	loss_train:0.003	loss_test:1.060	acc_train:100.00%	acc_test:68.97%
# epoch:125	loss_train:0.011	loss_test:1.054	acc_train:100.00%	acc_test:69.13%
# epoch:126	loss_train:0.002	loss_test:1.059	acc_train:100.00%	acc_test:69.17%
# epoch:127	loss_train:0.008	loss_test:1.060	acc_train:100.00%	acc_test:69.10%
# epoch:128	loss_train:0.001	loss_test:1.054	acc_train:100.00%	acc_test:69.50%
# epoch:129	loss_train:0.003	loss_test:1.052	acc_train:100.00%	acc_test:69.77%
# epoch:130	loss_train:0.003	loss_test:1.065	acc_train:100.00%	acc_test:69.40%
# epoch:131	loss_train:0.001	loss_test:1.057	acc_train:100.00%	acc_test:69.43%
# epoch:132	loss_train:0.009	loss_test:1.063	acc_train:100.00%	acc_test:69.73%
# epoch:133	loss_train:0.005	loss_test:1.069	acc_train:100.00%	acc_test:69.80%
# epoch:134	loss_train:0.005	loss_test:1.070	acc_train:100.00%	acc_test:69.37%
# epoch:135	loss_train:0.001	loss_test:1.067	acc_train:100.00%	acc_test:70.23%
# epoch:136	loss_train:0.001	loss_test:1.059	acc_train:100.00%	acc_test:70.40%
# epoch:137	loss_train:0.002	loss_test:1.077	acc_train:100.00%	acc_test:69.47%
# epoch:138	loss_train:0.003	loss_test:1.088	acc_train:100.00%	acc_test:69.70%
# epoch:139	loss_train:0.003	loss_test:1.097	acc_train:100.00%	acc_test:69.50%
# epoch:140	loss_train:0.008	loss_test:1.079	acc_train:100.00%	acc_test:69.97%
# epoch:141	loss_train:0.025	loss_test:1.080	acc_train:100.00%	acc_test:70.17%
# epoch:142	loss_train:0.002	loss_test:1.086	acc_train:100.00%	acc_test:69.83%
# epoch:143	loss_train:0.005	loss_test:1.091	acc_train:100.00%	acc_test:69.83%
# epoch:144	loss_train:0.002	loss_test:1.098	acc_train:100.00%	acc_test:69.77%
# epoch:145	loss_train:0.005	loss_test:1.103	acc_train:100.00%	acc_test:69.83%
# epoch:146	loss_train:0.003	loss_test:1.107	acc_train:100.00%	acc_test:69.20%
# epoch:147	loss_train:0.004	loss_test:1.117	acc_train:100.00%	acc_test:69.37%
# epoch:148	loss_train:0.002	loss_test:1.140	acc_train:100.00%	acc_test:68.23%
# epoch:149	loss_train:0.005	loss_test:1.108	acc_train:100.00%	acc_test:69.77%
# epoch:150	loss_train:0.006	loss_test:1.120	acc_train:100.00%	acc_test:70.10%
# epoch:151	loss_train:0.002	loss_test:1.108	acc_train:100.00%	acc_test:70.27%
# epoch:152	loss_train:0.005	loss_test:1.086	acc_train:100.00%	acc_test:70.30%
# epoch:153	loss_train:0.006	loss_test:1.110	acc_train:100.00%	acc_test:69.87%
# epoch:154	loss_train:0.003	loss_test:1.110	acc_train:100.00%	acc_test:70.03%
# epoch:155	loss_train:0.005	loss_test:1.114	acc_train:100.00%	acc_test:70.30%
# epoch:156	loss_train:0.001	loss_test:1.119	acc_train:100.00%	acc_test:70.40%
# epoch:157	loss_train:0.001	loss_test:1.124	acc_train:100.00%	acc_test:70.03%
# epoch:158	loss_train:0.011	loss_test:1.118	acc_train:100.00%	acc_test:70.30%
# epoch:159	loss_train:0.001	loss_test:1.129	acc_train:100.00%	acc_test:70.13%
# epoch:160	loss_train:0.016	loss_test:1.125	acc_train:100.00%	acc_test:70.43%
# epoch:161	loss_train:0.001	loss_test:1.141	acc_train:100.00%	acc_test:70.00%
# epoch:162	loss_train:0.005	loss_test:1.131	acc_train:100.00%	acc_test:69.80%
# epoch:163	loss_train:0.003	loss_test:1.150	acc_train:100.00%	acc_test:70.53%
# epoch:164	loss_train:0.006	loss_test:1.162	acc_train:100.00%	acc_test:69.60%
# epoch:165	loss_train:0.003	loss_test:1.155	acc_train:100.00%	acc_test:69.97%
# epoch:166	loss_train:0.003	loss_test:1.149	acc_train:100.00%	acc_test:70.57%
# epoch:167	loss_train:0.001	loss_test:1.160	acc_train:100.00%	acc_test:69.90%
# epoch:168	loss_train:0.005	loss_test:1.151	acc_train:100.00%	acc_test:70.17%
# epoch:169	loss_train:0.046	loss_test:1.157	acc_train:100.00%	acc_test:70.00%
# epoch:170	loss_train:0.001	loss_test:1.156	acc_train:100.00%	acc_test:69.60%
# epoch:171	loss_train:0.001	loss_test:1.178	acc_train:100.00%	acc_test:69.57%
# epoch:172	loss_train:0.003	loss_test:1.156	acc_train:100.00%	acc_test:69.93%
# epoch:173	loss_train:0.002	loss_test:1.163	acc_train:100.00%	acc_test:70.40%
# epoch:174	loss_train:0.001	loss_test:1.156	acc_train:100.00%	acc_test:69.93%
# epoch:175	loss_train:0.003	loss_test:1.178	acc_train:100.00%	acc_test:70.20%
# epoch:176	loss_train:0.000	loss_test:1.164	acc_train:100.00%	acc_test:69.57%
# epoch:177	loss_train:0.003	loss_test:1.174	acc_train:100.00%	acc_test:69.97%
# epoch:178	loss_train:0.002	loss_test:1.161	acc_train:100.00%	acc_test:70.07%
# epoch:179	loss_train:0.006	loss_test:1.174	acc_train:100.00%	acc_test:70.23%
# epoch:180	loss_train:0.002	loss_test:1.171	acc_train:100.00%	acc_test:70.07%
# epoch:181	loss_train:0.001	loss_test:1.167	acc_train:100.00%	acc_test:70.27%
# epoch:182	loss_train:0.000	loss_test:1.159	acc_train:100.00%	acc_test:70.43%
# epoch:183	loss_train:0.004	loss_test:1.179	acc_train:100.00%	acc_test:70.03%
# epoch:184	loss_train:0.002	loss_test:1.185	acc_train:100.00%	acc_test:69.73%
# epoch:185	loss_train:0.001	loss_test:1.172	acc_train:100.00%	acc_test:70.30%
# epoch:186	loss_train:0.001	loss_test:1.185	acc_train:100.00%	acc_test:69.80%
# epoch:187	loss_train:0.000	loss_test:1.197	acc_train:100.00%	acc_test:69.43%
# epoch:188	loss_train:0.005	loss_test:1.160	acc_train:100.00%	acc_test:70.80%
# epoch:189	loss_train:0.001	loss_test:1.192	acc_train:100.00%	acc_test:69.70%
# epoch:190	loss_train:0.002	loss_test:1.180	acc_train:100.00%	acc_test:70.23%
# epoch:191	loss_train:0.000	loss_test:1.193	acc_train:100.00%	acc_test:69.80%
# epoch:192	loss_train:0.001	loss_test:1.185	acc_train:100.00%	acc_test:70.93%
# epoch:193	loss_train:0.001	loss_test:1.191	acc_train:100.00%	acc_test:70.23%
# epoch:194	loss_train:0.001	loss_test:1.193	acc_train:100.00%	acc_test:69.80%
# epoch:195	loss_train:0.001	loss_test:1.199	acc_train:100.00%	acc_test:68.97%
# epoch:196	loss_train:0.005	loss_test:1.192	acc_train:100.00%	acc_test:69.63%
# epoch:197	loss_train:0.001	loss_test:1.190	acc_train:100.00%	acc_test:70.17%
# epoch:198	loss_train:0.000	loss_test:1.205	acc_train:100.00%	acc_test:69.90%
# epoch:199	loss_train:0.001	loss_test:1.217	acc_train:100.00%	acc_test:69.60%
# epoch:200	loss_train:0.001	loss_test:1.217	acc_train:100.00%	acc_test:70.80%
# epoch:201	loss_train:0.001	loss_test:1.215	acc_train:100.00%	acc_test:69.70%
# epoch:202	loss_train:0.002	loss_test:1.212	acc_train:100.00%	acc_test:70.47%
# epoch:203	loss_train:0.000	loss_test:1.205	acc_train:100.00%	acc_test:70.50%
# epoch:204	loss_train:0.000	loss_test:1.218	acc_train:100.00%	acc_test:70.33%
# epoch:205	loss_train:0.001	loss_test:1.231	acc_train:100.00%	acc_test:69.40%
# epoch:206	loss_train:0.000	loss_test:1.178	acc_train:100.00%	acc_test:70.63%
# epoch:207	loss_train:0.000	loss_test:1.213	acc_train:100.00%	acc_test:70.33%
# epoch:208	loss_train:0.000	loss_test:1.216	acc_train:100.00%	acc_test:70.47%
# epoch:209	loss_train:0.001	loss_test:1.215	acc_train:100.00%	acc_test:70.37%
# epoch:210	loss_train:0.001	loss_test:1.232	acc_train:100.00%	acc_test:69.73%
# epoch:211	loss_train:0.002	loss_test:1.245	acc_train:100.00%	acc_test:69.73%
# epoch:212	loss_train:0.005	loss_test:1.221	acc_train:100.00%	acc_test:70.20%
# epoch:213	loss_train:0.000	loss_test:1.226	acc_train:100.00%	acc_test:69.73%
# epoch:214	loss_train:0.001	loss_test:1.234	acc_train:100.00%	acc_test:70.03%
# epoch:215	loss_train:0.000	loss_test:1.230	acc_train:100.00%	acc_test:70.20%
# epoch:216	loss_train:0.002	loss_test:1.226	acc_train:100.00%	acc_test:70.63%
# epoch:217	loss_train:0.000	loss_test:1.220	acc_train:100.00%	acc_test:69.80%
# epoch:218	loss_train:0.003	loss_test:1.237	acc_train:100.00%	acc_test:69.90%
# epoch:219	loss_train:0.001	loss_test:1.245	acc_train:100.00%	acc_test:70.00%
# epoch:220	loss_train:0.001	loss_test:1.236	acc_train:100.00%	acc_test:69.83%
# epoch:221	loss_train:0.001	loss_test:1.243	acc_train:100.00%	acc_test:70.00%
# epoch:222	loss_train:0.003	loss_test:1.265	acc_train:100.00%	acc_test:69.53%
# epoch:223	loss_train:0.000	loss_test:1.248	acc_train:100.00%	acc_test:69.90%
# epoch:224	loss_train:0.003	loss_test:1.227	acc_train:100.00%	acc_test:70.07%
# epoch:225	loss_train:0.003	loss_test:1.233	acc_train:100.00%	acc_test:70.67%
# epoch:226	loss_train:0.001	loss_test:1.259	acc_train:100.00%	acc_test:70.23%
# epoch:227	loss_train:0.003	loss_test:1.239	acc_train:100.00%	acc_test:70.50%
# epoch:228	loss_train:0.000	loss_test:1.263	acc_train:100.00%	acc_test:69.50%
# epoch:229	loss_train:0.000	loss_test:1.259	acc_train:100.00%	acc_test:70.20%
# epoch:230	loss_train:0.000	loss_test:1.274	acc_train:100.00%	acc_test:69.97%
# epoch:231	loss_train:0.000	loss_test:1.272	acc_train:100.00%	acc_test:69.30%
# epoch:232	loss_train:0.008	loss_test:1.246	acc_train:100.00%	acc_test:70.43%
# epoch:233	loss_train:0.001	loss_test:1.259	acc_train:100.00%	acc_test:69.80%
# epoch:234	loss_train:0.002	loss_test:1.231	acc_train:100.00%	acc_test:71.03%
# epoch:235	loss_train:0.001	loss_test:1.258	acc_train:100.00%	acc_test:70.00%
# epoch:236	loss_train:0.000	loss_test:1.226	acc_train:100.00%	acc_test:70.93%
# epoch:237	loss_train:0.001	loss_test:1.251	acc_train:100.00%	acc_test:70.13%
# epoch:238	loss_train:0.000	loss_test:1.250	acc_train:100.00%	acc_test:70.37%
# epoch:239	loss_train:0.000	loss_test:1.243	acc_train:100.00%	acc_test:70.27%
# epoch:240	loss_train:0.011	loss_test:1.273	acc_train:100.00%	acc_test:69.43%
# epoch:241	loss_train:0.001	loss_test:1.248	acc_train:100.00%	acc_test:70.70%
# epoch:242	loss_train:0.001	loss_test:1.253	acc_train:100.00%	acc_test:70.33%
# epoch:243	loss_train:0.000	loss_test:1.268	acc_train:100.00%	acc_test:70.27%
# epoch:244	loss_train:0.001	loss_test:1.287	acc_train:100.00%	acc_test:69.73%
# epoch:245	loss_train:0.001	loss_test:1.226	acc_train:100.00%	acc_test:71.13%
# epoch:246	loss_train:0.000	loss_test:1.239	acc_train:100.00%	acc_test:70.47%
# epoch:247	loss_train:0.000	loss_test:1.252	acc_train:100.00%	acc_test:70.30%
# epoch:248	loss_train:0.000	loss_test:1.252	acc_train:100.00%	acc_test:70.30%
# epoch:249	loss_train:0.001	loss_test:1.254	acc_train:100.00%	acc_test:70.83%
# epoch:250	loss_train:0.002	loss_test:1.265	acc_train:100.00%	acc_test:70.40%
# epoch:251	loss_train:0.000	loss_test:1.267	acc_train:100.00%	acc_test:70.83%
# epoch:252	loss_train:0.000	loss_test:1.284	acc_train:100.00%	acc_test:69.73%
# epoch:253	loss_train:0.000	loss_test:1.279	acc_train:100.00%	acc_test:71.07%
# epoch:254	loss_train:0.001	loss_test:1.290	acc_train:100.00%	acc_test:70.00%
# epoch:255	loss_train:0.000	loss_test:1.271	acc_train:100.00%	acc_test:70.23%
# epoch:256	loss_train:0.001	loss_test:1.282	acc_train:100.00%	acc_test:70.07%
# epoch:257	loss_train:0.001	loss_test:1.294	acc_train:100.00%	acc_test:69.43%
# epoch:258	loss_train:0.000	loss_test:1.289	acc_train:100.00%	acc_test:70.47%
# epoch:259	loss_train:0.000	loss_test:1.295	acc_train:100.00%	acc_test:70.33%
# epoch:260	loss_train:0.000	loss_test:1.299	acc_train:100.00%	acc_test:70.33%
# epoch:261	loss_train:0.000	loss_test:1.312	acc_train:100.00%	acc_test:69.90%
# epoch:262	loss_train:0.000	loss_test:1.319	acc_train:100.00%	acc_test:70.10%
# epoch:263	loss_train:0.000	loss_test:1.287	acc_train:100.00%	acc_test:70.70%
# epoch:264	loss_train:0.001	loss_test:1.313	acc_train:100.00%	acc_test:70.17%
# epoch:265	loss_train:0.000	loss_test:1.313	acc_train:100.00%	acc_test:70.17%
# epoch:266	loss_train:0.000	loss_test:1.312	acc_train:100.00%	acc_test:70.07%
# epoch:267	loss_train:0.000	loss_test:1.302	acc_train:100.00%	acc_test:69.93%
# epoch:268	loss_train:0.001	loss_test:1.296	acc_train:100.00%	acc_test:70.37%
# epoch:269	loss_train:0.001	loss_test:1.320	acc_train:100.00%	acc_test:70.20%
# epoch:270	loss_train:0.000	loss_test:1.313	acc_train:100.00%	acc_test:70.17%
# epoch:271	loss_train:0.000	loss_test:1.314	acc_train:100.00%	acc_test:70.50%
# epoch:272	loss_train:0.000	loss_test:1.328	acc_train:100.00%	acc_test:70.23%
# epoch:273	loss_train:0.000	loss_test:1.294	acc_train:100.00%	acc_test:70.30%
# epoch:274	loss_train:0.000	loss_test:1.287	acc_train:100.00%	acc_test:71.07%
# epoch:275	loss_train:0.000	loss_test:1.300	acc_train:100.00%	acc_test:70.43%
# epoch:276	loss_train:0.000	loss_test:1.322	acc_train:100.00%	acc_test:70.70%
# epoch:277	loss_train:0.000	loss_test:1.321	acc_train:100.00%	acc_test:70.83%
# epoch:278	loss_train:0.002	loss_test:1.311	acc_train:100.00%	acc_test:70.60%
# epoch:279	loss_train:0.000	loss_test:1.298	acc_train:100.00%	acc_test:70.30%
# epoch:280	loss_train:0.001	loss_test:1.246	acc_train:100.00%	acc_test:71.07%
# epoch:281	loss_train:0.000	loss_test:1.307	acc_train:100.00%	acc_test:70.33%
# epoch:282	loss_train:0.000	loss_test:1.318	acc_train:100.00%	acc_test:70.50%
# epoch:283	loss_train:0.000	loss_test:1.320	acc_train:100.00%	acc_test:70.60%
# epoch:284	loss_train:0.000	loss_test:1.312	acc_train:100.00%	acc_test:69.97%
# epoch:285	loss_train:0.000	loss_test:1.313	acc_train:100.00%	acc_test:70.33%
# epoch:286	loss_train:0.000	loss_test:1.288	acc_train:100.00%	acc_test:71.00%
# epoch:287	loss_train:0.000	loss_test:1.308	acc_train:100.00%	acc_test:70.57%
# epoch:288	loss_train:0.001	loss_test:1.301	acc_train:100.00%	acc_test:70.47%
# epoch:289	loss_train:0.000	loss_test:1.333	acc_train:100.00%	acc_test:70.97%
# epoch:290	loss_train:0.001	loss_test:1.316	acc_train:100.00%	acc_test:69.83%
# epoch:291	loss_train:0.000	loss_test:1.290	acc_train:100.00%	acc_test:70.43%
# epoch:292	loss_train:0.000	loss_test:1.300	acc_train:100.00%	acc_test:70.50%
# epoch:293	loss_train:0.000	loss_test:1.326	acc_train:100.00%	acc_test:70.53%
# epoch:294	loss_train:0.001	loss_test:1.299	acc_train:100.00%	acc_test:71.10%
# epoch:295	loss_train:0.000	loss_test:1.283	acc_train:100.00%	acc_test:71.17%
# epoch:296	loss_train:0.000	loss_test:1.296	acc_train:100.00%	acc_test:71.17%
# epoch:297	loss_train:0.000	loss_test:1.300	acc_train:100.00%	acc_test:70.80%
# epoch:298	loss_train:0.000	loss_test:1.325	acc_train:100.00%	acc_test:69.90%
# epoch:299	loss_train:0.001	loss_test:1.277	acc_train:100.00%	acc_test:71.60%
# epoch:300	loss_train:0.000	loss_test:1.307	acc_train:100.00%	acc_test:70.63%
# epoch:301	loss_train:0.001	loss_test:1.273	acc_train:100.00%	acc_test:70.77%
# epoch:302	loss_train:0.000	loss_test:1.301	acc_train:100.00%	acc_test:71.30%
# epoch:303	loss_train:0.000	loss_test:1.322	acc_train:100.00%	acc_test:70.70%
# epoch:304	loss_train:0.003	loss_test:1.325	acc_train:100.00%	acc_test:69.30%
# epoch:305	loss_train:0.001	loss_test:1.291	acc_train:100.00%	acc_test:70.77%
# epoch:306	loss_train:0.000	loss_test:1.310	acc_train:100.00%	acc_test:71.30%
# epoch:307	loss_train:0.000	loss_test:1.308	acc_train:100.00%	acc_test:71.00%
# epoch:308	loss_train:0.000	loss_test:1.320	acc_train:100.00%	acc_test:70.70%
# epoch:309	loss_train:0.000	loss_test:1.316	acc_train:100.00%	acc_test:71.07%
# epoch:310	loss_train:0.000	loss_test:1.305	acc_train:100.00%	acc_test:70.87%
# epoch:311	loss_train:0.000	loss_test:1.314	acc_train:100.00%	acc_test:71.20%
# epoch:312	loss_train:0.000	loss_test:1.327	acc_train:100.00%	acc_test:70.67%
# epoch:313	loss_train:0.000	loss_test:1.340	acc_train:100.00%	acc_test:70.33%
# epoch:314	loss_train:0.000	loss_test:1.339	acc_train:100.00%	acc_test:70.73%
# epoch:315	loss_train:0.000	loss_test:1.344	acc_train:100.00%	acc_test:70.77%
# epoch:316	loss_train:0.001	loss_test:1.353	acc_train:100.00%	acc_test:70.03%
# epoch:317	loss_train:0.001	loss_test:1.354	acc_train:100.00%	acc_test:70.43%
# epoch:318	loss_train:0.000	loss_test:1.324	acc_train:100.00%	acc_test:70.73%
# epoch:319	loss_train:0.001	loss_test:1.330	acc_train:100.00%	acc_test:70.43%
# epoch:320	loss_train:0.000	loss_test:1.331	acc_train:100.00%	acc_test:71.23%
# epoch:321	loss_train:0.001	loss_test:1.348	acc_train:100.00%	acc_test:70.53%
# epoch:322	loss_train:0.002	loss_test:1.339	acc_train:100.00%	acc_test:71.10%
# epoch:323	loss_train:0.001	loss_test:1.325	acc_train:100.00%	acc_test:71.07%
# epoch:324	loss_train:0.001	loss_test:1.323	acc_train:100.00%	acc_test:70.80%
# epoch:325	loss_train:0.001	loss_test:1.334	acc_train:100.00%	acc_test:71.03%
# epoch:326	loss_train:0.000	loss_test:1.333	acc_train:100.00%	acc_test:71.23%
# epoch:327	loss_train:0.001	loss_test:1.347	acc_train:100.00%	acc_test:70.90%
# epoch:328	loss_train:0.000	loss_test:1.337	acc_train:100.00%	acc_test:71.30%
# epoch:329	loss_train:0.000	loss_test:1.344	acc_train:100.00%	acc_test:71.87%
# epoch:330	loss_train:0.001	loss_test:1.329	acc_train:100.00%	acc_test:71.60%
# epoch:331	loss_train:0.000	loss_test:1.346	acc_train:100.00%	acc_test:71.67%
# epoch:332	loss_train:0.001	loss_test:1.350	acc_train:100.00%	acc_test:71.30%
# epoch:333	loss_train:0.000	loss_test:1.357	acc_train:100.00%	acc_test:70.93%
# epoch:334	loss_train:0.002	loss_test:1.358	acc_train:100.00%	acc_test:70.83%
# epoch:335	loss_train:0.000	loss_test:1.350	acc_train:100.00%	acc_test:71.17%
# epoch:336	loss_train:0.000	loss_test:1.330	acc_train:100.00%	acc_test:71.33%
# epoch:337	loss_train:0.000	loss_test:1.299	acc_train:100.00%	acc_test:71.53%
# epoch:338	loss_train:0.000	loss_test:1.316	acc_train:100.00%	acc_test:71.97%
# epoch:339	loss_train:0.000	loss_test:1.323	acc_train:100.00%	acc_test:71.43%
# epoch:340	loss_train:0.001	loss_test:1.290	acc_train:100.00%	acc_test:71.13%
# epoch:341	loss_train:0.000	loss_test:1.330	acc_train:100.00%	acc_test:70.80%
# epoch:342	loss_train:0.000	loss_test:1.333	acc_train:100.00%	acc_test:71.63%
# epoch:343	loss_train:0.000	loss_test:1.333	acc_train:100.00%	acc_test:71.57%
# epoch:344	loss_train:0.000	loss_test:1.322	acc_train:100.00%	acc_test:70.93%
# epoch:345	loss_train:0.000	loss_test:1.347	acc_train:100.00%	acc_test:70.67%
# epoch:346	loss_train:0.001	loss_test:1.343	acc_train:100.00%	acc_test:70.93%
# epoch:347	loss_train:0.005	loss_test:1.348	acc_train:100.00%	acc_test:71.17%
# epoch:348	loss_train:0.000	loss_test:1.356	acc_train:100.00%	acc_test:70.93%
# epoch:349	loss_train:0.000	loss_test:1.346	acc_train:100.00%	acc_test:71.70%
# epoch:350	loss_train:0.000	loss_test:1.362	acc_train:100.00%	acc_test:71.47%
# epoch:351	loss_train:0.000	loss_test:1.379	acc_train:100.00%	acc_test:70.87%
# epoch:352	loss_train:0.000	loss_test:1.381	acc_train:100.00%	acc_test:71.33%
# epoch:353	loss_train:0.000	loss_test:1.381	acc_train:100.00%	acc_test:71.53%
# epoch:354	loss_train:0.000	loss_test:1.380	acc_train:100.00%	acc_test:71.60%
# epoch:355	loss_train:0.000	loss_test:1.376	acc_train:100.00%	acc_test:71.10%
# epoch:356	loss_train:0.000	loss_test:1.371	acc_train:100.00%	acc_test:71.67%
# epoch:357	loss_train:0.000	loss_test:1.353	acc_train:100.00%	acc_test:71.57%
# epoch:358	loss_train:0.000	loss_test:1.370	acc_train:100.00%	acc_test:71.00%
# epoch:359	loss_train:0.000	loss_test:1.359	acc_train:100.00%	acc_test:70.90%
# epoch:360	loss_train:0.000	loss_test:1.361	acc_train:100.00%	acc_test:70.90%
# epoch:361	loss_train:0.000	loss_test:1.391	acc_train:100.00%	acc_test:70.53%
# epoch:362	loss_train:0.000	loss_test:1.369	acc_train:100.00%	acc_test:71.03%
# epoch:363	loss_train:0.000	loss_test:1.370	acc_train:100.00%	acc_test:71.37%
# epoch:364	loss_train:0.001	loss_test:1.372	acc_train:100.00%	acc_test:71.20%
# epoch:365	loss_train:0.001	loss_test:1.352	acc_train:100.00%	acc_test:70.87%
# epoch:366	loss_train:0.001	loss_test:1.342	acc_train:100.00%	acc_test:71.07%
# epoch:367	loss_train:0.000	loss_test:1.368	acc_train:100.00%	acc_test:70.63%
# epoch:368	loss_train:0.000	loss_test:1.377	acc_train:100.00%	acc_test:70.50%
# epoch:369	loss_train:0.000	loss_test:1.382	acc_train:100.00%	acc_test:70.13%
# epoch:370	loss_train:0.000	loss_test:1.369	acc_train:100.00%	acc_test:71.10%
# epoch:371	loss_train:0.002	loss_test:1.352	acc_train:100.00%	acc_test:70.40%
# epoch:372	loss_train:0.000	loss_test:1.366	acc_train:100.00%	acc_test:70.90%
# epoch:373	loss_train:0.000	loss_test:1.341	acc_train:100.00%	acc_test:70.43%
# epoch:374	loss_train:0.000	loss_test:1.345	acc_train:100.00%	acc_test:70.93%
# epoch:375	loss_train:0.000	loss_test:1.363	acc_train:100.00%	acc_test:70.83%
# epoch:376	loss_train:0.000	loss_test:1.349	acc_train:100.00%	acc_test:71.57%
# epoch:377	loss_train:0.000	loss_test:1.365	acc_train:100.00%	acc_test:70.83%
# epoch:378	loss_train:0.000	loss_test:1.370	acc_train:100.00%	acc_test:70.97%
# epoch:379	loss_train:0.000	loss_test:1.367	acc_train:100.00%	acc_test:70.83%
# epoch:380	loss_train:0.000	loss_test:1.375	acc_train:100.00%	acc_test:71.03%
# epoch:381	loss_train:0.001	loss_test:1.377	acc_train:100.00%	acc_test:70.87%
# epoch:382	loss_train:0.000	loss_test:1.365	acc_train:100.00%	acc_test:71.07%
# epoch:383	loss_train:0.002	loss_test:1.361	acc_train:100.00%	acc_test:70.93%
# epoch:384	loss_train:0.000	loss_test:1.327	acc_train:100.00%	acc_test:71.20%
# epoch:385	loss_train:0.000	loss_test:1.347	acc_train:100.00%	acc_test:71.40%
# epoch:386	loss_train:0.000	loss_test:1.366	acc_train:100.00%	acc_test:70.80%
# epoch:387	loss_train:0.000	loss_test:1.371	acc_train:100.00%	acc_test:70.60%
# epoch:388	loss_train:0.000	loss_test:1.384	acc_train:100.00%	acc_test:70.97%
# epoch:389	loss_train:0.000	loss_test:1.383	acc_train:100.00%	acc_test:71.00%
# epoch:390	loss_train:0.000	loss_test:1.317	acc_train:100.00%	acc_test:71.33%
# epoch:391	loss_train:0.000	loss_test:1.362	acc_train:100.00%	acc_test:71.10%
# epoch:392	loss_train:0.000	loss_test:1.382	acc_train:100.00%	acc_test:70.77%
# epoch:393	loss_train:0.000	loss_test:1.383	acc_train:100.00%	acc_test:71.53%
# epoch:394	loss_train:0.000	loss_test:1.390	acc_train:100.00%	acc_test:71.57%
# epoch:395	loss_train:0.000	loss_test:1.389	acc_train:100.00%	acc_test:70.77%
# epoch:396	loss_train:0.000	loss_test:1.386	acc_train:100.00%	acc_test:70.97%
# epoch:397	loss_train:0.000	loss_test:1.394	acc_train:100.00%	acc_test:71.07%
# epoch:398	loss_train:0.000	loss_test:1.393	acc_train:100.00%	acc_test:70.83%
# epoch:399	loss_train:0.000	loss_test:1.395	acc_train:100.00%	acc_test:71.03%
# epoch:400	loss_train:0.000	loss_test:1.400	acc_train:100.00%	acc_test:70.77%
# epoch:401	loss_train:0.001	loss_test:1.399	acc_train:100.00%	acc_test:71.57%
# epoch:402	loss_train:0.000	loss_test:1.397	acc_train:100.00%	acc_test:71.43%
# epoch:403	loss_train:0.000	loss_test:1.404	acc_train:100.00%	acc_test:71.03%
# epoch:404	loss_train:0.000	loss_test:1.339	acc_train:100.00%	acc_test:71.20%
# epoch:405	loss_train:0.000	loss_test:1.376	acc_train:100.00%	acc_test:70.60%
# epoch:406	loss_train:0.000	loss_test:1.366	acc_train:100.00%	acc_test:71.20%
# epoch:407	loss_train:0.000	loss_test:1.376	acc_train:100.00%	acc_test:71.63%
# epoch:408	loss_train:0.000	loss_test:1.368	acc_train:100.00%	acc_test:72.00%
# epoch:409	loss_train:0.001	loss_test:1.360	acc_train:100.00%	acc_test:71.57%
# epoch:410	loss_train:0.001	loss_test:1.393	acc_train:100.00%	acc_test:71.27%
# epoch:411	loss_train:0.000	loss_test:1.384	acc_train:100.00%	acc_test:71.30%
# epoch:412	loss_train:0.000	loss_test:1.400	acc_train:100.00%	acc_test:71.27%
# epoch:413	loss_train:0.000	loss_test:1.402	acc_train:100.00%	acc_test:71.53%
# epoch:414	loss_train:0.000	loss_test:1.405	acc_train:100.00%	acc_test:71.30%
# epoch:415	loss_train:0.000	loss_test:1.408	acc_train:100.00%	acc_test:71.30%
# epoch:416	loss_train:0.000	loss_test:1.387	acc_train:100.00%	acc_test:71.30%
# epoch:417	loss_train:0.001	loss_test:1.412	acc_train:100.00%	acc_test:70.93%
# epoch:418	loss_train:0.000	loss_test:1.417	acc_train:100.00%	acc_test:70.93%
# epoch:419	loss_train:0.000	loss_test:1.420	acc_train:100.00%	acc_test:70.27%
# epoch:420	loss_train:0.000	loss_test:1.412	acc_train:100.00%	acc_test:71.03%
# epoch:421	loss_train:0.000	loss_test:1.412	acc_train:100.00%	acc_test:70.87%
# epoch:422	loss_train:0.000	loss_test:1.416	acc_train:100.00%	acc_test:70.70%
# epoch:423	loss_train:0.000	loss_test:1.428	acc_train:100.00%	acc_test:70.80%
# epoch:424	loss_train:0.000	loss_test:1.444	acc_train:100.00%	acc_test:70.57%
# epoch:425	loss_train:0.000	loss_test:1.430	acc_train:100.00%	acc_test:70.50%
# epoch:426	loss_train:0.001	loss_test:1.418	acc_train:100.00%	acc_test:70.90%
# epoch:427	loss_train:0.000	loss_test:1.422	acc_train:100.00%	acc_test:70.93%
# epoch:428	loss_train:0.000	loss_test:1.421	acc_train:100.00%	acc_test:70.80%
# epoch:429	loss_train:0.000	loss_test:1.415	acc_train:100.00%	acc_test:70.80%
# epoch:430	loss_train:0.001	loss_test:1.445	acc_train:100.00%	acc_test:70.33%
# epoch:431	loss_train:0.000	loss_test:1.427	acc_train:100.00%	acc_test:70.93%
# epoch:432	loss_train:0.000	loss_test:1.431	acc_train:100.00%	acc_test:71.03%
# epoch:433	loss_train:0.000	loss_test:1.432	acc_train:100.00%	acc_test:71.27%
# epoch:434	loss_train:0.000	loss_test:1.408	acc_train:100.00%	acc_test:71.37%
# epoch:435	loss_train:0.000	loss_test:1.423	acc_train:100.00%	acc_test:70.87%
# epoch:436	loss_train:0.000	loss_test:1.453	acc_train:100.00%	acc_test:70.40%
# epoch:437	loss_train:0.000	loss_test:1.432	acc_train:100.00%	acc_test:71.33%
# epoch:438	loss_train:0.000	loss_test:1.405	acc_train:100.00%	acc_test:71.77%
# epoch:439	loss_train:0.000	loss_test:1.415	acc_train:100.00%	acc_test:71.37%
# epoch:440	loss_train:0.000	loss_test:1.421	acc_train:100.00%	acc_test:71.23%
# epoch:441	loss_train:0.000	loss_test:1.431	acc_train:100.00%	acc_test:70.97%
# epoch:442	loss_train:0.000	loss_test:1.432	acc_train:100.00%	acc_test:70.67%
# epoch:443	loss_train:0.000	loss_test:1.427	acc_train:100.00%	acc_test:70.93%
# epoch:444	loss_train:0.000	loss_test:1.433	acc_train:100.00%	acc_test:71.07%
# epoch:445	loss_train:0.000	loss_test:1.420	acc_train:100.00%	acc_test:71.63%
# epoch:446	loss_train:0.000	loss_test:1.424	acc_train:100.00%	acc_test:71.70%
# epoch:447	loss_train:0.000	loss_test:1.399	acc_train:100.00%	acc_test:70.90%
# epoch:448	loss_train:0.000	loss_test:1.385	acc_train:100.00%	acc_test:72.03%
# epoch:449	loss_train:0.000	loss_test:1.401	acc_train:100.00%	acc_test:71.80%
# epoch:450	loss_train:0.000	loss_test:1.400	acc_train:100.00%	acc_test:71.47%
# epoch:451	loss_train:0.000	loss_test:1.404	acc_train:100.00%	acc_test:71.73%
# epoch:452	loss_train:0.000	loss_test:1.418	acc_train:100.00%	acc_test:71.10%
# epoch:453	loss_train:0.001	loss_test:1.423	acc_train:100.00%	acc_test:71.10%
# epoch:454	loss_train:0.000	loss_test:1.424	acc_train:100.00%	acc_test:71.27%
# epoch:455	loss_train:0.000	loss_test:1.443	acc_train:100.00%	acc_test:71.23%
# epoch:456	loss_train:0.000	loss_test:1.450	acc_train:100.00%	acc_test:70.97%
# epoch:457	loss_train:0.000	loss_test:1.460	acc_train:100.00%	acc_test:70.50%
# epoch:458	loss_train:0.000	loss_test:1.428	acc_train:100.00%	acc_test:71.73%
# epoch:459	loss_train:0.000	loss_test:1.399	acc_train:100.00%	acc_test:71.63%
# epoch:460	loss_train:0.000	loss_test:1.428	acc_train:100.00%	acc_test:71.47%
# epoch:461	loss_train:0.000	loss_test:1.405	acc_train:100.00%	acc_test:71.30%
# epoch:462	loss_train:0.000	loss_test:1.421	acc_train:100.00%	acc_test:71.73%
# epoch:463	loss_train:0.000	loss_test:1.428	acc_train:100.00%	acc_test:71.73%
# epoch:464	loss_train:0.000	loss_test:1.427	acc_train:100.00%	acc_test:71.47%
# epoch:465	loss_train:0.000	loss_test:1.439	acc_train:100.00%	acc_test:71.43%
# epoch:466	loss_train:0.000	loss_test:1.408	acc_train:100.00%	acc_test:72.13%
# epoch:467	loss_train:0.000	loss_test:1.444	acc_train:100.00%	acc_test:71.57%
# epoch:468	loss_train:0.000	loss_test:1.446	acc_train:100.00%	acc_test:71.07%
# epoch:469	loss_train:0.000	loss_test:1.425	acc_train:100.00%	acc_test:72.10%
# epoch:470	loss_train:0.000	loss_test:1.447	acc_train:100.00%	acc_test:71.53%
# epoch:471	loss_train:0.004	loss_test:1.388	acc_train:100.00%	acc_test:71.70%
# epoch:472	loss_train:0.000	loss_test:1.409	acc_train:100.00%	acc_test:71.60%
# epoch:473	loss_train:0.000	loss_test:1.417	acc_train:100.00%	acc_test:72.13%
# epoch:474	loss_train:0.000	loss_test:1.412	acc_train:100.00%	acc_test:71.70%
# epoch:475	loss_train:0.001	loss_test:1.430	acc_train:100.00%	acc_test:71.90%
# epoch:476	loss_train:0.000	loss_test:1.434	acc_train:100.00%	acc_test:71.53%
# epoch:477	loss_train:0.000	loss_test:1.439	acc_train:100.00%	acc_test:71.50%
# epoch:478	loss_train:0.000	loss_test:1.445	acc_train:100.00%	acc_test:71.17%
# epoch:479	loss_train:0.000	loss_test:1.445	acc_train:100.00%	acc_test:71.43%
# epoch:480	loss_train:0.000	loss_test:1.464	acc_train:100.00%	acc_test:71.27%
# epoch:481	loss_train:0.000	loss_test:1.456	acc_train:100.00%	acc_test:72.00%
# epoch:482	loss_train:0.000	loss_test:1.433	acc_train:100.00%	acc_test:71.20%
# epoch:483	loss_train:0.000	loss_test:1.461	acc_train:100.00%	acc_test:71.27%
# epoch:484	loss_train:0.000	loss_test:1.458	acc_train:100.00%	acc_test:71.90%
# epoch:485	loss_train:0.000	loss_test:1.475	acc_train:100.00%	acc_test:71.13%
# epoch:486	loss_train:0.000	loss_test:1.467	acc_train:100.00%	acc_test:71.60%
# epoch:487	loss_train:0.000	loss_test:1.459	acc_train:100.00%	acc_test:71.57%
# epoch:488	loss_train:0.000	loss_test:1.478	acc_train:100.00%	acc_test:70.70%
# epoch:489	loss_train:0.000	loss_test:1.481	acc_train:100.00%	acc_test:71.67%
# epoch:490	loss_train:0.000	loss_test:1.478	acc_train:100.00%	acc_test:71.27%
# epoch:491	loss_train:0.000	loss_test:1.387	acc_train:100.00%	acc_test:71.53%
# epoch:492	loss_train:0.000	loss_test:1.400	acc_train:100.00%	acc_test:72.00%
# epoch:493	loss_train:0.000	loss_test:1.418	acc_train:100.00%	acc_test:71.93%
# epoch:494	loss_train:0.000	loss_test:1.439	acc_train:100.00%	acc_test:71.53%
# epoch:495	loss_train:0.000	loss_test:1.435	acc_train:100.00%	acc_test:71.63%
# epoch:496	loss_train:0.000	loss_test:1.448	acc_train:100.00%	acc_test:71.33%
# epoch:497	loss_train:0.000	loss_test:1.448	acc_train:100.00%	acc_test:71.30%
# epoch:498	loss_train:0.000	loss_test:1.456	acc_train:100.00%	acc_test:71.87%
# epoch:499	loss_train:0.000	loss_test:1.457	acc_train:100.00%	acc_test:71.33%
